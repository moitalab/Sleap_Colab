# %% [markdown]
# #SLEAP_AI.ipnyb

# %% [markdown]
# #Description
# ---------
# This notebook runs SLEAP.ai in the colab Virtual Machine.
#
# It uses the power of NVIDIA Tesla T4 GPU to take the best out of SLEAP running it's deep learning neural networks faster.
#
# The system used is condacolab since it helps bypass default python limitations from colab
#
# SLEAP is run inside an environment where it has the necessary drivers.

# %% [markdown]
# Run order
#
# 1.   Choose the Paths.
# 2.   Prepare the environment
# 3.   Run SLEAP
# 4.   Output the predictions

# %% [markdown]
# SLEAP.ai DOI 🔗 https://doi.org/10.1038/s41592-022-01426-1
#
# Moita Lab 🔗 https://moitalab.org/

# %% [markdown]
# #Define Paths

# %%
import os
from IPython.display import display, clear_output
import ipywidgets as widgets
from google.colab import drive
from ipyfilechooser import FileChooser

# 1. Mount Google Drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 2. Repository Settings (Fixed Model)
REPO_URL = "https://github.com/moitalab/Sleap_Colab.git"
REPO_DIR = "/content/Sleap_Colab"

# Automatic repository download (including best_model.h5 via LFS)
if not os.path.exists(REPO_DIR):
    print("🚀 Downloading model and scripts from GitHub (Moita Lab)...")
    # !git clone {REPO_URL}
else:
    print("✅ GitHub model is already prepared.")

# --- SELECTION INTERFACE ---
chooser_exp = FileChooser('/content/drive/MyDrive/')
chooser_exp.title = '<b>Select Experiment Folder (Root)</b>'
chooser_exp.show_only_dirs = True

save_button = widgets.Button(
    description='Confirm Configuration',
    button_style='success',
    icon='check',
    layout=widgets.Layout(width='300px')
)

output_log = widgets.Output()

def on_confirm_clicked(b):
    with output_log:
        clear_output()
        exp_root = chooser_exp.selected_path
        if not exp_root:
            print("❌ Error: Please select the experiment folder in Drive!")
            return

        # Standard repository subfolder paths
        crop_raw = os.path.join(exp_root, "PostProcessing", "CropRaw")
        arenas = os.path.join(exp_root, "PostProcessing", "Arenas")
        pose_folder = os.path.join(exp_root, "PostProcessing", "Pose")

        # Ensure the output directory exists
        os.makedirs(pose_folder, exist_ok=True)

        # Save paths for the Bash environment
        with open('/content/sleap_paths.env', 'w') as f:
            f.write(f'export VIDEO_FOLDER="{crop_raw}"\n')
            f.write(f'export ARENAS_FOLDER="{arenas}"\n')
            f.write(f'export OUTPUT_FOLDER="{pose_folder}"\n')
            f.write(f'export MODEL_PATH="{REPO_DIR}"\n')

        print("-" * 50)
        print("✅ PIPELINE CONFIGURED!")
        print(f"🧠 Model: Loaded from GitHub")
        print(f"📍 Videos: {crop_raw}")
        print("-" * 50)

save_button.on_click(on_confirm_clicked)
display(chooser_exp, save_button, output_log)
# Out:
# Mounted at /content/drive
# 🚀 A descarregar modelo e scripts do GitHub (Moita Lab)...
# Cloning into 'Sleap_Colab'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 9 (delta 1), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 13.90 KiB | 273.00 KiB/s, done.
# Resolving deltas: 100% (1/1), done.
# FileChooser(path='/content/drive/MyDrive', filename='', title='<b>Selecionar Pasta da Experiência (Root)</b>',…
# Button(button_style='success', description='Confirmar Configuração', icon='check', layout=Layout(width='300px'…
# Output()

# %% [markdown]
# #Enviroment preparation

# %%
# !pip install -q condacolab
import condacolab
condacolab.install() # Runtime will restart
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...

# %%
# !mamba create -y -n sleap_env -c conda-forge -c nvidia -c sleap -c anaconda \
    python=3.7 \
    sleap=1.3.4 \
    tensorflow=2.7.0 \
    cudatoolkit=11.3.1 \
    cudnn=8.2.1.32 \
    pandas=1.3.5 \
    scipy=1.7.3 \
    matplotlib=3.5.3
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Transaction
#
#   Prefix: /usr/local/envs/sleap_env
#
#   Updating specs:
#
#    - python=3.7
#    - sleap=1.3.4
#    - tensorflow=2.7.0
#    - cudatoolkit=11.3.1
#    - cudnn=8.2.1.32
#    - pandas=1.3.5
#    - scipy=1.7.3
#    - matplotlib=3.5.3
#
#
#   Package                    Version  Build                   Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   + cuda-nvcc                11.3.58  h2467b9f_0              nvidia            57MB
#   + python_abi                   3.7  4_cp37m                 conda-forge        6kB
#   + ld_impl_linux-64          2.45.1  bootstrap_ha15bf96_1    conda-forge      726kB
#   + libgomp                   15.2.0  he0feb66_18             conda-forge      603kB
#   + _openmp_mutex                4.5  20_gnu                  conda-forge       29kB
#   + libgcc                    15.2.0  he0feb66_18             conda-forge        1MB
#   + c-ares                    1.34.6  hb03c661_0              conda-forge      208kB
#   + libbrotlicommon            1.2.0  hb03c661_1              conda-forge       80kB
#   + yaml                       0.2.5  h280c20c_3              conda-forge       85kB
#   + xorg-renderproto          0.11.1  hb9d3cd8_1003           conda-forge       12kB
#   + libexpat                   2.7.4  hecca717_0              conda-forge       77kB
#   + keyutils                   1.6.3  hb9d3cd8_0              conda-forge      134kB
#   + libiconv                    1.18  h3b78370_2              conda-forge      790kB
#   + libuuid                   2.41.3  h5347b49_0              conda-forge       40kB
#   + xorg-xproto               7.0.31  hb9d3cd8_1008           conda-forge       73kB
#   + xorg-kbproto               1.0.7  hb9d3cd8_1003           conda-forge       30kB
#   + xorg-xextproto             7.3.0  hb9d3cd8_1004           conda-forge       31kB
#   + xorg-libice                1.1.2  hb9d3cd8_0              conda-forge       59kB
#   + bzip2                      1.0.8  hda65f42_9              conda-forge      260kB
#   + xorg-libxdmcp              1.1.5  hb03c661_1              conda-forge       21kB
#   + xorg-libxau               1.0.12  hb03c661_1              conda-forge       15kB
#   + pthread-stubs                0.4  hb9d3cd8_1002           conda-forge        8kB
#   + libwebp-base               1.6.0  hd42ef1d_0              conda-forge      429kB
#   + liblzma                    5.8.2  hb03c661_0              conda-forge      113kB
#   + libffi                     3.4.6  h2dba641_1              conda-forge       57kB
#   + libgfortran5              15.2.0  h68bc16d_18             conda-forge        2MB
#   + ncurses                      6.5  h2d0b736_3              conda-forge      892kB
#   + libnsl                     2.0.1  hb9d3cd8_1              conda-forge       34kB
#   + libstdcxx                 15.2.0  h934c35e_18             conda-forge        6MB
#   + libgcc-ng                 15.2.0  h69a702a_18             conda-forge       28kB
#   + libbrotlienc               1.2.0  hb03c661_1              conda-forge      298kB
#   + libbrotlidec               1.2.0  hb03c661_1              conda-forge       35kB
#   + expat                      2.7.4  hecca717_0              conda-forge      145kB
#   + libgettextpo              0.25.1  h3f43e3d_1              conda-forge      188kB
#   + gettext-tools             0.25.1  h3f43e3d_1              conda-forge        4MB
#   + xorg-libsm                 1.2.6  he73a12e_0              conda-forge       28kB
#   + xz-tools                   5.8.2  hb03c661_0              conda-forge       96kB
#   + xz-gpl-tools               5.8.2  ha02ee65_0              conda-forge       34kB
#   + liblzma-devel              5.8.2  hb03c661_0              conda-forge      465kB
#   + libgfortran               15.2.0  h69a702a_18             conda-forge       28kB
#   + libedit             3.1.20250104  pl5321h7949ede_0        conda-forge      135kB
#   + readline                     8.3  h853b02a_0              conda-forge      345kB
#   + libasprintf               0.25.1  h3f43e3d_1              conda-forge       54kB
#   + nspr                        4.38  h29cc59b_0              conda-forge      229kB
#   + lerc                       4.0.0  h0aef613_1              conda-forge      264kB
#   + pixman                    0.46.4  h54a6638_1              conda-forge      451kB
#   + graphite2                 1.3.14  hecca717_2              conda-forge      100kB
#   + libstdcxx-ng              15.2.0  hdf11a46_18             conda-forge       28kB
#   + libev                       4.33  hd590300_2              conda-forge     Cached
#   + alsa-lib                 1.2.3.2  h166bdaf_0              conda-forge      567kB
#   + libsodium                 1.0.18  h36c2ea0_1              conda-forge      375kB
#   + x264                  1!161.3030  h7f98852_1              conda-forge        3MB
#   + lame                       3.100  h166bdaf_1003           conda-forge      508kB
#   + nettle                       3.6  he412f7d_0              conda-forge        7MB
#   + libxcb                      1.13  h7f98852_1004           conda-forge      400kB
#   + libdeflate                  1.14  h166bdaf_0              conda-forge       83kB
#   + jpeg                          9e  h0b41bf4_3              conda-forge      240kB
#   + libzlib                   1.2.13  h4ab18f5_6              conda-forge       62kB
#   + brotli-bin                 1.2.0  hb03c661_1              conda-forge       21kB
#   + libgettextpo-devel        0.25.1  h3f43e3d_1              conda-forge       37kB
#   + xz                         5.8.2  ha02ee65_0              conda-forge       24kB
#   + libgfortran-ng            15.2.0  h69a702a_18             conda-forge       28kB
#   + libasprintf-devel         0.25.1  h3f43e3d_1              conda-forge       35kB
#   + geos                      3.11.0  h27087fc_0              conda-forge        2MB
#   + gmp                        6.3.0  hac33072_2              conda-forge      460kB
#   + icu                         68.2  h9c3ff4c_0              conda-forge       14MB
#   + cudatoolkit               11.3.1  hb98b00a_13             conda-forge      633MB
#   + zeromq                     4.3.5  h59595ed_1              conda-forge      343kB
#   + gnutls                    3.6.13  h85f3911_1              conda-forge        2MB
#   + xorg-libx11                1.8.4  h0b41bf4_0              conda-forge      830kB
#   + jasper                   1.900.1  h07fcdf6_1006           conda-forge      293kB
#   + libllvm11                 11.1.0  he0ac6c6_5              conda-forge       30MB
#   + zstd                       1.5.6  ha6fb4c9_0              conda-forge     Cached
#   + pcre2                      10.43  hcad00b1_0              conda-forge      951kB
#   + libpng                    1.6.43  h2797004_0              conda-forge      288kB
#   + tk                        8.6.13  noxft_h4845f30_101      conda-forge     Cached
#   + libsqlite                 3.46.0  hde9e2c9_0              conda-forge      865kB
#   + zlib                      1.2.13  h4ab18f5_6              conda-forge       93kB
#   + brotli                     1.2.0  hed03a55_1              conda-forge       20kB
#   + libopenblas               0.3.25  pthreads_h413a1c8_0     conda-forge        6MB
#   + gettext                   0.25.1  h3f43e3d_1              conda-forge      541kB
#   + cudnn                   8.2.1.32  h86fa8c9_0              conda-forge      707MB
#   + xorg-libxext               1.3.4  h0b41bf4_2              conda-forge       50kB
#   + xorg-libxrender           0.9.10  h7f98852_1003           conda-forge       33kB
#   + libclang                  11.1.0  default_ha53f305_1      conda-forge       20MB
#   + libtiff                    4.4.0  h82bc61c_5              conda-forge      485kB
#   + libglib                   2.80.2  hf974151_0              conda-forge        4MB
#   + freetype                  2.12.1  h267a509_2              conda-forge      635kB
#   + nss                        3.100  hca3bf56_0              conda-forge        2MB
#   + sqlite                    3.46.0  h6d4b2fc_0              conda-forge      860kB
#   + libxml2                   2.9.12  h72842e0_0              conda-forge      791kB
#   + openh264                   2.1.1  h780b84a_0              conda-forge        2MB
#   + libprotobuf               3.16.0  h780b84a_0              conda-forge        3MB
#   + libblas                    3.9.0  20_linux64_openblas     conda-forge       14kB
#   + openjpeg                   2.5.0  h7d73246_1              conda-forge      546kB
#   + lcms2                       2.14  h6ed2654_0              conda-forge      262kB
#   + gstreamer                 1.18.5  h9f60fe5_3              conda-forge        2MB
#   + glib-tools                2.80.2  hb6ce0ca_0              conda-forge      114kB
#   + dbus                      1.13.6  h5008d03_3              conda-forge      619kB
#   + fontconfig                2.14.2  h14ed4e7_0              conda-forge      272kB
#   + libxslt                   1.1.33  h15afd5d_2              conda-forge      535kB
#   + libxkbcommon               1.0.3  he3ba5ed_0              conda-forge      595kB
#   + ffmpeg                     4.3.2  h37c90e5_3              conda-forge       10MB
#   + libcblas                   3.9.0  20_linux64_openblas     conda-forge       14kB
#   + liblapack                  3.9.0  20_linux64_openblas     conda-forge       14kB
#   + cairo                     1.16.0  h6cf1ce9_1008           conda-forge        2MB
#   + liblapacke                 3.9.0  20_linux64_openblas     conda-forge       14kB
#   + harfbuzz                   2.9.1  h83ec7ef_1              conda-forge        2MB
#   + ca-certificates         2026.1.4  hbd8a1cb_0              conda-forge      147kB
#   + openssl                   1.1.1w  hd590300_0              conda-forge        2MB
#   + mysql-common              8.0.32  h14678bc_0              conda-forge      803kB
#   + libevent                  2.1.10  h9b69904_4              conda-forge        1MB
#   + krb5                      1.20.1  hf9c8cef_0              conda-forge        1MB
#   + libssh2                   1.10.0  haa6b8db_3              conda-forge      239kB
#   + libnghttp2                1.51.0  hdcd2b5c_0              conda-forge      623kB
#   + python                    3.7.12  hb7a2778_100_cpython    conda-forge       60MB
#   + mysql-libs                8.0.32  h54cf53e_0              conda-forge        2MB
#   + libcurl                   7.87.0  h6312ad2_0              conda-forge      347kB
#   + setuptools                59.8.0  py37h89c1867_1          conda-forge        1MB
#   + hdf5                      1.10.6  nompi_h6a2412b_1114     conda-forge        3MB
#   + libpq                      12.15  h37d81fd_1              anaconda           3MB
#   + wheel                     0.42.0  pyhd8ed1ab_0            conda-forge       58kB
#   + pip                         24.0  pyhd8ed1ab_0            conda-forge        1MB
#   + locket                     1.0.0  pyhd8ed1ab_0            conda-forge        8kB
#   + fsspec                  2023.1.0  pyhd8ed1ab_0            conda-forge      109kB
#   + munkres                    1.1.4  pyh9f0ad1d_0            conda-forge       12kB
#   + pyparsing                  3.1.4  pyhd8ed1ab_0            conda-forge       90kB
#   + cycler                    0.11.0  pyhd8ed1ab_0            conda-forge       10kB
#   + certifi                2024.8.30  pyhd8ed1ab_0            conda-forge      164kB
#   + toolz                     0.12.1  pyhd8ed1ab_0            conda-forge       52kB
#   + cloudpickle                2.2.1  pyhd8ed1ab_0            conda-forge       28kB
#   + threadpoolctl              3.1.0  pyh8a188c0_0            conda-forge       18kB
#   + joblib                     1.3.2  pyhd8ed1ab_0            conda-forge      221kB
#   + cached_property            1.5.2  pyha770c72_1            conda-forge       11kB
#   + mdurl                      0.1.2  pyhd8ed1ab_0            conda-forge       15kB
#   + six                       1.16.0  pyh6c4a22f_0            conda-forge       14kB
#   + packaging                   23.2  pyhd8ed1ab_0            conda-forge       49kB
#   + pygments                  2.17.2  pyhd8ed1ab_0            conda-forge      860kB
#   + typing_extensions          4.7.1  pyha770c72_0            conda-forge       36kB
#   + jsonpickle                   1.2  py_0                    conda-forge       28kB
#   + attrs                     21.4.0  pyhd8ed1ab_0            conda-forge       50kB
#   + pytz                      2024.2  pyhd8ed1ab_0            conda-forge      187kB
#   + jsmin                      3.0.1  pyhd8ed1ab_0            conda-forge       16kB
#   + partd                      1.4.1  pyhd8ed1ab_0            conda-forge       21kB
#   + cached-property            1.5.2  hd8ed1ab_1              conda-forge        4kB
#   + python-dateutil            2.9.0  pyhd8ed1ab_0            conda-forge      223kB
#   + qtpy                       2.4.2  pyhdecd6ff_0            conda-forge       62kB
#   + typing-extensions          4.7.1  hd8ed1ab_0              conda-forge       10kB
#   + markdown-it-py             2.2.0  pyhd8ed1ab_0            conda-forge       62kB
#   + cattrs                     1.1.1  pyhd8ed1ab_0            conda-forge       18kB
#   + rich                      13.8.1  pyhd8ed1ab_0            conda-forge      185kB
#   + unicodedata2              14.0.0  py37h540881e_1          conda-forge      508kB
#   + glib                      2.80.2  hf974151_0              conda-forge      600kB
#   + pyzmq                     24.0.1  py37h0c0c2a8_0          conda-forge      512kB
#   + pyyaml                       6.0  py37h540881e_4          conda-forge      182kB
#   + python-rapidjson             1.9  py37hd23a5d3_0          conda-forge      248kB
#   + psutil                     5.9.3  py37h540881e_0          conda-forge      357kB
#   + tornado                      6.2  py37h540881e_0          conda-forge      666kB
#   + pyqt5-sip                4.19.18  py37hcd2ae1e_8          conda-forge      317kB
#   + pillow                     9.2.0  py37h850a105_2          conda-forge       47MB
#   + numpy                     1.21.6  py37h976b520_0          conda-forge        6MB
#   + cytoolz                   0.12.0  py37h540881e_0          conda-forge      389kB
#   + protobuf                  3.16.0  py37hcd2ae1e_0          conda-forge      350kB
#   + kiwisolver                 1.4.4  py37h7cecad7_0          conda-forge       75kB
#   + fonttools                 4.38.0  py37h540881e_0          conda-forge        2MB
#   + gst-plugins-base          1.14.5  h0935bb2_2              conda-forge        7MB
#   + imagecodecs-lite       2019.12.3  py37hc105733_5          conda-forge      181kB
#   + pywavelets                 1.3.0  py37hda87dfa_1          conda-forge        5MB
#   + shapely                    1.8.5  py37ha4e3bd1_0          conda-forge      362kB
#   + h5py                       3.1.0  nompi_py37h1e651dc_100  conda-forge        1MB
#   + scipy                      1.7.3  py37hf2a6cf1_0          conda-forge       23MB
#   + pandas                     1.3.5  py37he8f5f7f_0          conda-forge       13MB
#   + matplotlib-base            3.5.3  py37hf395dca_2          conda-forge        8MB
#   + qt                        5.12.9  h9d6b050_2              conda-forge      104MB
#   + scikit-learn                 1.0  py37hf0f1638_1          conda-forge        8MB
#   + pyside2                   5.13.2  py37hfa98aef_7          conda-forge       14MB
#   + pyqt-impl                 5.12.3  py37hac37412_8          conda-forge        6MB
#   + libopencv                  4.5.3  py37h25009ff_1          conda-forge       36MB
#   + pyqtwebengine             5.12.1  py37he336c9b_8          conda-forge      179kB
#   + pyqtchart                   5.12  py37he336c9b_8          conda-forge      263kB
#   + py-opencv                  4.5.3  py37h6531663_1          conda-forge        1MB
#   + pyqt                      5.12.3  py37h89c1867_8          conda-forge       22kB
#   + opencv                     4.5.3  py37h89c1867_1          conda-forge       21kB
#   + matplotlib                 3.5.3  py37h89c1867_2          conda-forge        7kB
#   + tensorflow                 2.7.0  py37hb93dfd8_3          sleap            515MB
#   + dask-core               2022.2.0  pyhd8ed1ab_0            conda-forge      822kB
#   + patsy                      0.5.6  pyhd8ed1ab_0            conda-forge      187kB
#   + imageio                   2.36.0  pyh12aca89_1            conda-forge      292kB
#   + tifffile                2020.6.3  py_0                    conda-forge      111kB
#   + pykalman                   0.9.7  pyhd8ed1ab_0            conda-forge      232kB
#   + scikit-video              1.1.11  pyh24bf2e0_0            conda-forge        2MB
#   + seaborn-base              0.12.2  pyhd8ed1ab_0            conda-forge      232kB
#   + networkx                     2.7  pyhd8ed1ab_0            conda-forge        2MB
#   + tensorflow-hub            0.13.0  pyh56297ac_0            conda-forge       77kB
#   + statsmodels               0.13.2  py37hda87dfa_0          conda-forge       12MB
#   + scikit-image              0.19.2  py37he8f5f7f_0          conda-forge       13MB
#   + seaborn                   0.12.2  hd8ed1ab_0              conda-forge        6kB
#   + imgaug                     0.4.0  pyhd8ed1ab_1            conda-forge      853kB
#   + sleap                      1.3.4  py37_2                  sleap              5MB
#
#   Summary:
#
#   Install: 199 packages
#
#   Total download: 2GB
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%python_abi                                           6.4kB @  59.2kB/s  0.1s
# libgomp                                            603.3kB @   4.4MB/s  0.1s
# _openmp_mutex                                       28.9kB @ 173.8kB/s  0.2s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (2)  ⣾  yaml                                                85.2kB @ 371.8kB/s  0.1s
# ld_impl_linux-64                                   725.8kB @   3.2MB/s  0.2s
# libgcc                                               1.0MB @   4.5MB/s  0.1s
# keyutils                                           134.1kB @ 535.8kB/s  0.1s
# xorg-xproto                                         73.3kB @ 257.6kB/s  0.1s
# xorg-libxau                                         15.3kB @  51.7kB/s  0.1s
# [+] 0.3s
# Downloading  (5)   1%
# Extracting   (7)  ⣾  liblzma                                            113.2kB @ 371.0kB/s  0.1s
# xorg-kbproto                                        30.2kB @  97.8kB/s  0.1s
# libgcc-ng                                           27.5kB @  73.9kB/s  0.1s
# expat                                              145.3kB @ 389.6kB/s  0.1s
# xorg-libsm                                          27.6kB @  74.0kB/s  0.1s
# ncurses                                            891.6kB @   2.3MB/s  0.1s
# [+] 0.4s
# Downloading  (5)   1%
# Extracting  (11)  ⣾  libstdcxx-ng                                        27.6kB @  63.3kB/s  0.1s
# liblzma-devel                                      465.1kB @   1.1MB/s  0.1s
# libgfortran                                         27.5kB @  62.1kB/s  0.1s
# libedit                                            134.7kB @ 272.6kB/s  0.1s
# [+] 0.5s
# Downloading  (5)   1%
# Extracting  (13)  ⣾  libzlib                                             61.6kB @ 119.8kB/s  0.1s
# lame                                               508.3kB @ 944.5kB/s  0.1s
# [+] 0.6s
# Downloading  (5)   2%
# Extracting  (13)  ⣾  xz                                                  24.1kB @  39.4kB/s  0.1s
# geos                                                 1.7MB @   2.6MB/s  0.1s
# [+] 0.7s
# Downloading  (5)   2%
# Extracting  (14)  ⣾  xorg-libx11                                        829.9kB @   1.2MB/s  0.1s
# pcre2                                              950.8kB @   1.3MB/s  0.1s
# x264                                                 2.6MB @   3.6MB/s  0.3s
# zlib                                                92.9kB @ 119.5kB/s  0.1s
# [+] 0.8s
# Downloading  (5)   3%
# Extracting  (17)  ⣾  xorg-libxrender                                     32.9kB @  40.7kB/s  0.1s
# gettext                                            541.4kB @ 668.6kB/s  0.1s
# sqlite                                             860.4kB @ 974.0kB/s  0.1s
# [+] 0.9s
# Downloading  (5)   4%
# Extracting  (18)  ⣾  libxml2                                            790.7kB @ 843.8kB/s  0.1s
# libglib                                              3.9MB @   4.0MB/s  0.2s
# lcms2                                              262.1kB @ 265.8kB/s  0.1s
# [+] 1.0s
# Downloading  (5)   4%
# Extracting  (20)  ⣾  dbus                                               618.6kB @ 608.3kB/s  0.1s
# harfbuzz                                             2.1MB @   1.9MB/s  0.1s
# [+] 1.1s
# Downloading  (5)   5%
# Extracting  (22)  ⣾  cuda-nvcc                                           56.8MB @  51.4MB/s  1.1s
# libxkbcommon                                       594.8kB @ 537.9kB/s  0.1s
# [+] 1.2s
# Downloading  (5)   5%
# Extracting  (24)  ⣾  libssh2                                            239.5kB @ 200.8kB/s  0.1s
# mysql-common                                       803.0kB @ 654.5kB/s  0.1s
# mysql-libs                                           1.5MB @   1.2MB/s  0.1s
# locket                                               8.2kB @   6.4kB/s  0.1s
# [+] 1.3s
# Downloading  (5)   6%
# Extracting  (27)  ⣾  pip                                                  1.4MB @   1.1MB/s  0.1s
# threadpoolctl                                       18.3kB @  13.3kB/s  0.1s
# hdf5                                                 3.2MB @   2.3MB/s  0.2s
# certifi                                            163.8kB @ 118.8kB/s  0.1s
# ffmpeg                                              10.3MB @   7.5MB/s  0.4s
# [+] 1.4s
# Downloading  (5)   6%
# Extracting  (31)  ⣾  six                                                 14.3kB @   9.9kB/s  0.1s
# jsonpickle                                          28.3kB @  19.4kB/s  0.1s
# [+] 1.5s
# Downloading  (5)   7%
# Extracting  (33)  ⣾  qtpy                                                62.4kB @  41.4kB/s  0.1s
# partd                                               20.7kB @  13.4kB/s  0.2s
# [+] 1.6s
# Downloading  (5)   7%
# Extracting  (35)  ⣾  glib                                               600.4kB @ 376.8kB/s  0.1s
# cattrs                                              18.3kB @  11.1kB/s  0.2s
# mdurl                                               14.7kB @   8.9kB/s  0.3s
# python-rapidjson                                   247.8kB @ 150.4kB/s  0.1s
# [+] 1.7s
# Downloading  (6)   8%
# Extracting  (37)  ⣾  kiwisolver                                          74.5kB @  43.2kB/s  0.1s
# cytoolz                                            388.6kB @ 225.1kB/s  0.1s
# pyqt5-sip                                          317.4kB @ 181.2kB/s  0.2s
# protobuf                                           349.9kB @ 199.2kB/s  0.1s
# [+] 1.8s
# Downloading  (5)   8%
# Extracting  (40)  ⣾  [+] 1.9s
# Downloading  (5)   8%
# Extracting  (38)  ⣾  [+] 2.0s
# Downloading  (5)   9%
# Extracting  (37)  ⣾  [+] 2.1s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.2s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.3s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.4s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.5s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.6s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.7s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.8s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 2.9s
# Downloading  (5)   9%
# Extracting  (36)  ⣾  [+] 3.0s
# Downloading  (5)   9%
# Extracting  (35)  ⣾  [+] 3.1s
# Downloading  (5)   9%
# Extracting  (35)  ⣾  [+] 3.2s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.3s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.4s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.5s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.6s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.7s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.8s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 3.9s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.0s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.1s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.2s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.3s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.4s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.5s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.6s
# Downloading  (5)   9%
# Extracting  (34)  ⣾  [+] 4.7s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 4.8s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 4.9s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.0s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.1s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.2s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.3s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.4s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.5s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.6s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.7s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.8s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 5.9s
# Downloading  (5)   9%
# Extracting  (33)  ⣾  [+] 6.0s
# Downloading  (5)  10%
# Extracting  (33)  ⣾  pyqt-impl                                            6.2MB @   1.0MB/s  4.3s
# [+] 6.1s
# Downloading  (5)  10%
# Extracting  (34)  ⣾  [+] 6.2s
# Downloading  (5)  11%
# Extracting  (34)  ⣾  scipy                                               22.8MB @   3.7MB/s  4.5s
# [+] 6.3s
# Downloading  (5)  12%
# Extracting  (35)  ⣾  dask-core                                          822.4kB @ 129.6kB/s  0.1s
# [+] 6.4s
# Downloading  (5)  13%
# Extracting  (36)  ⣾  tifffile                                           111.2kB @  17.3kB/s  0.1s
# [+] 6.5s
# Downloading  (5)  13%
# Extracting  (37)  ⣾  seaborn-base                                       231.9kB @  35.6kB/s  0.1s
# libopencv                                           36.2MB @   5.5MB/s  4.8s
# [+] 6.6s
# Downloading  (5)  14%
# Extracting  (39)  ⣾  [+] 6.7s
# Downloading  (5)  14%
# Extracting  (39)  ⣾  imgaug                                             853.1kB @ 127.2kB/s  0.2s
# libbrotlicommon                                     80.0kB @  11.8kB/s  0.1s
# [+] 6.8s
# Downloading  (5)  15%
# Extracting  (41)  ⣾  libiconv                                           790.2kB @ 115.0kB/s  0.1s
# [+] 6.9s
# Downloading  (5)  15%
# Extracting  (42)  ⣾  xorg-libice                                         58.6kB @   8.4kB/s  0.1s
# statsmodels                                         11.7MB @   1.7MB/s  0.5s
# [+] 7.0s
# Downloading  (5)  16%
# Extracting  (45)  ⣾  pthread-stubs                                        8.3kB @   1.2kB/s  0.0s
# libbrotlienc                                       298.4kB @  42.3kB/s  0.1s
# [+] 7.1s
# Downloading  (5)  17%
# Extracting  (46)  ⣾  libgfortran5                                         2.5MB @ 348.4kB/s  0.1s
# readline                                           345.1kB @  48.0kB/s  0.1s
# [+] 7.2s
# Downloading  (4)  17%
# Extracting  (47)  ⣾  lerc                                               264.2kB @  36.4kB/s  0.1s
# gettext-tools                                        3.6MB @ 500.8kB/s  0.2s
# [+] 7.3s
# Downloading  (5)  18%
# Extracting  (50)  ⣾  libxcb                                             399.9kB @  54.5kB/s  0.1s
# [+] 7.4s
# Downloading  (5)  18%
# Extracting  (51)  ⣾  brotli-bin                                          21.0kB @   2.8kB/s  0.1s
# [+] 7.5s
# Downloading  (5)  19%
# Extracting  (52)  ⣾  libasprintf-devel                                   34.7kB @   4.6kB/s  0.1s
# alsa-lib                                           567.0kB @  74.9kB/s  0.3s
# [+] 7.6s
# Downloading  (5)  19%
# Extracting  (53)  ⣾  zeromq                                             343.4kB @  45.0kB/s  0.1s
# qt                                                 104.3MB @  13.6MB/s  5.9s
# brotli                                              20.1kB @   2.6kB/s  0.1s
# [+] 7.7s
# Downloading  (5)  20%
# Extracting  (55)  ⣾  xorg-libxext                                        50.1kB @   6.5kB/s  0.1s
# freetype                                           635.0kB @  81.9kB/s  0.1s
# [+] 7.8s
# Downloading  (5)  20%
# Extracting  (57)  ⣾  libprotobuf                                          2.6MB @ 328.0kB/s  0.1s
# [+] 7.9s
# Downloading  (5)  21%
# Extracting  (58)  ⣾  gstreamer                                            2.1MB @ 264.1kB/s  0.2s
# libxslt                                            534.6kB @  67.0kB/s  0.1s
# [+] 8.0s
# Downloading  (5)  21%
# Extracting  (60)  ⣾  cairo                                                1.6MB @ 193.2kB/s  0.1s
# [+] 8.1s
# Downloading  (5)  22%
# Extracting  (61)  ⣾  openssl                                              2.0MB @ 241.2kB/s  0.1s
# [+] 8.2s
# Downloading  (5)  22%
# Extracting  (61)  ⣾  libnghttp2                                         622.7kB @  75.7kB/s  0.2s
# setuptools                                           1.1MB @ 130.1kB/s  0.1s
# [+] 8.3s
# Downloading  (5)  22%
# Extracting  (63)  ⣾  fsspec                                             108.9kB @  13.1kB/s  0.1s
# cycler                                              10.3kB @   1.2kB/s  0.1s
# cached_property                                     11.1kB @   1.3kB/s  0.1s
# [+] 8.4s
# Downloading  (5)  23%
# Extracting  (66)  ⣾  pytz                                               187.0kB @  22.2kB/s  0.1s
# joblib                                             221.2kB @  26.1kB/s  0.2s
# [+] 8.5s
# Downloading  (5)  23%
# Extracting  (67)  ⣾  python-dateutil                                    222.7kB @  26.1kB/s  0.1s
# libllvm11                                           30.2MB @   3.5MB/s  1.0s
# rich                                               185.4kB @  21.6kB/s  0.1s
# [+] 8.6s
# Downloading  (5)  24%
# Extracting  (70)  ⣾  pyyaml                                             182.0kB @  21.2kB/s  0.1s
# psutil                                             356.8kB @  41.2kB/s  0.1s
# [+] 8.7s
# Downloading  (5)  24%
# Extracting  (72)  ⣾  [+] 8.8s
# Downloading  (5)  24%
# Extracting  (72)  ⣾  [+] 8.9s
# Downloading  (5)  25%
# Extracting  (72)  ⣾  gst-plugins-base                                     7.1MB @ 796.7kB/s  0.3s
# matplotlib-base                                      7.7MB @ 862.4kB/s  0.3s
# shapely                                            361.5kB @  40.4kB/s  0.4s
# [+] 9.0s
# Downloading  (5)  25%
# Extracting  (75)  ⣾  patsy                                              187.2kB @  20.8kB/s  0.1s
# pyqtchart                                          263.3kB @  29.2kB/s  0.1s
# [+] 9.1s
# Downloading  (5)  25%
# Extracting  (77)  ⣾  pyqtwebengine                                      178.7kB @  19.6kB/s  0.2s
# scikit-video                                         2.3MB @ 247.1kB/s  0.1s
# [+] 9.2s
# Downloading  (5)  26%
# Extracting  (79)  ⣾  libuuid                                             40.3kB @   4.4kB/s  0.1s
# c-ares                                             207.9kB @  22.5kB/s  0.1s
# xorg-libxdmcp                                       20.6kB @   2.2kB/s  0.1s
# [+] 9.3s
# Downloading  (5)  26%
# Extracting  (82)  ⣾  libnsl                                              33.7kB @   3.6kB/s  0.1s
# libasprintf                                         53.6kB @   5.7kB/s  0.1s
# [+] 9.4s
# Downloading  (5)  27%
# Extracting  (84)  ⣾  libgettextpo                                       188.3kB @  20.0kB/s  0.1s
# scikit-image                                        12.6MB @   1.3MB/s  0.4s
# graphite2                                           99.6kB @  10.5kB/s  0.1s
# libgfortran-ng                                      27.5kB @   2.9kB/s  0.1s
# [+] 9.5s
# Downloading  (5)  27%
# Extracting  (87)  ⣾  libdeflate                                          82.7kB @   8.7kB/s  0.1s
# libsqlite                                          865.3kB @  90.5kB/s  0.1s
# gnutls                                               2.1MB @ 218.8kB/s  0.1s
# [+] 9.6s
# Downloading  (5)  27%
# Extracting  (91)  ⣾  glib-tools                                         114.4kB @  11.8kB/s  0.1s
# openh264                                             1.6MB @ 164.0kB/s  0.1s
# [+] 9.7s
# Downloading  (5)  27%
# Extracting  (93)  ⣾  liblapack                                           14.3kB @   1.5kB/s  0.1s
# liblapacke                                          14.4kB @   1.5kB/s  0.1s
# libcurl                                            347.4kB @  35.5kB/s  0.1s
# munkres                                             12.5kB @   1.3kB/s  0.1s
# [+] 9.8s
# Downloading  (5)  28%
# Extracting  (95)  ⣾  cloudpickle                                         27.9kB @   2.8kB/s  0.0s
# typing_extensions                                   36.3kB @   3.7kB/s  0.1s
# [+] 9.9s
# Downloading  (5)  28%
# Extracting  (98)  ⣾  cached-property                                      4.1kB @ 417.0 B/s  0.1s
# unicodedata2                                       508.2kB @  51.1kB/s  0.1s
# libclang                                            20.2MB @   2.0MB/s  0.4s
# [+] 10.0s
# Downloading  (5)   29%
# Extracting  (101)  ⣾  [+] 10.1s
# Downloading  (5)   29%
# Extracting  (100)  ⣾  imagecodecs-lite                                   181.3kB @  17.8kB/s  0.2s
# [+] 10.2s
# Downloading  (5)   30%
# Extracting  (101)  ⣾  [+] 10.3s
# Downloading  (5)   30%
# Extracting  (101)  ⣾  py-opencv                                            1.2MB @ 111.5kB/s  0.2s
# [+] 10.4s
# Downloading  (5)   31%
# Extracting  (102)  ⣾  pandas                                              13.3MB @   1.3MB/s  0.5s
# [+] 10.5s
# Downloading  (5)   31%
# Extracting  (103)  ⣾  networkx                                             1.6MB @ 153.0kB/s  0.1s
# [+] 10.6s
# Downloading  (5)   32%
# Extracting  (104)  ⣾  [+] 10.7s
# Downloading  (5)   32%
# Extracting  (104)  ⣾  [+] 10.8s
# Downloading  (5)   33%
# Extracting  (103)  ⣾  [+] 10.9s
# Downloading  (5)   34%
# Extracting  (103)  ⣾  pillow                                              47.2MB @   4.3MB/s  1.0s
# opencv                                              21.4kB @   2.0kB/s  4.9s
# xorg-xextproto                                      30.5kB @   2.8kB/s  0.0s
# xz-tools                                            96.1kB @   8.7kB/s  0.0s
# [+] 11.0s
# Downloading  (5)   34%
# Extracting  (106)  ⣾  libffi                                              57.4kB @   5.2kB/s  0.1s
# pixman                                             451.0kB @  40.8kB/s  0.1s
# [+] 11.1s
# Downloading  (5)   34%
# Extracting  (109)  ⣾  jpeg                                               240.4kB @  21.6kB/s  0.1s
# [+] 11.2s
# Downloading  (5)   35%
# Extracting  (110)  ⣾  [+] 11.3s
# Downloading  (5)   35%
# Extracting  (110)  ⣾  icu                                                 13.8MB @   1.2MB/s  0.3s
# [+] 11.4s
# Downloading  (5)   36%
# Extracting  (111)  ⣾  nss                                                  2.0MB @ 179.5kB/s  0.1s
# libopenblas                                          5.5MB @ 483.8kB/s  0.3s
# fontconfig                                         272.0kB @  23.7kB/s  0.1s
# [+] 11.5s
# Downloading  (5)   36%
# Extracting  (114)  ⣾  libevent                                             1.2MB @ 100.4kB/s  0.1s
# toolz                                               52.4kB @   4.5kB/s  0.1s
# [+] 11.6s
# Downloading  (5)   37%
# Extracting  (116)  ⣾  attrs                                               50.0kB @   4.3kB/s  0.1s
# [+] 11.7s
# Downloading  (5)   38%
# Extracting  (117)  ⣾  markdown-it-py                                      62.4kB @   5.3kB/s  0.1s
# [+] 11.8s
# Downloading  (5)   38%
# Extracting  (115)  ⣾  [+] 11.9s
# Downloading  (5)   39%
# Extracting  (114)  ⣾  numpy                                                6.4MB @ 536.4kB/s  0.2s
# [+] 12.0s
# Downloading  (5)   39%
# Extracting  (115)  ⣾  libpq                                                3.0MB @ 247.4kB/s  0.6s
# h5py                                                 1.3MB @ 103.5kB/s  0.2s
# [+] 12.1s
# Downloading  (5)   40%
# Extracting  (117)  ⣾  pyqt                                                22.5kB @   1.8kB/s  0.1s
# [+] 12.2s
# Downloading  (5)   41%
# Extracting  (118)  ⣾  xorg-renderproto                                    11.9kB @ 965.0 B/s  0.1s
# [+] 12.3s
# Downloading  (5)   41%
# Extracting  (117)  ⣾  [+] 12.4s
# Downloading  (5)   41%
# Extracting  (117)  ⣾  sleap                                                4.5MB @ 365.4kB/s  1.9s
# xz-gpl-tools                                        33.8kB @   2.7kB/s  0.1s
# [+] 12.5s
# Downloading  (5)   42%
# Extracting  (118)  ⣾  [+] 12.6s
# Downloading  (5)   42%
# Extracting  (117)  ⣾  nettle                                               6.8MB @ 536.3kB/s  0.2s
# jasper                                             292.7kB @  23.1kB/s  0.1s
# [+] 12.7s
# Downloading  (5)   43%
# Extracting  (119)  ⣾  libwebp-base                                       429.0kB @  33.6kB/s  0.5s
# libtiff                                            484.8kB @  38.0kB/s  0.1s
# [+] 12.8s
# Downloading  (5)   43%
# Extracting  (119)  ⣾  libcblas                                            14.4kB @   1.1kB/s  0.1s
# [+] 12.9s
# Downloading  (5)   44%
# Extracting  (120)  ⣾  packaging                                           49.5kB @   3.8kB/s  0.1s
# [+] 13.0s
# Downloading  (5)   44%
# Extracting  (120)  ⣾  typing-extensions                                   10.1kB @ 773.0 B/s  0.1s
# [+] 13.1s
# Downloading  (5)   45%
# Extracting  (121)  ⣾  [+] 13.2s
# Downloading  (5)   45%
# Extracting  (121)  ⣾  [+] 13.3s
# Downloading  (5)   46%
# Extracting  (121)  ⣾  [+] 13.4s
# Downloading  (5)   47%
# Extracting  (121)  ⣾  fonttools                                            2.0MB @ 151.6kB/s  0.4s
# [+] 13.5s
# Downloading  (5)   48%
# Extracting  (122)  ⣾  [+] 13.6s
# Downloading  (5)   48%
# Extracting  (122)  ⣾  [+] 13.7s
# Downloading  (5)   49%
# Extracting  (122)  ⣾  [+] 13.8s
# Downloading  (5)   50%
# Extracting  (121)  ⣾  pyside2                                             14.2MB @   1.0MB/s  0.4s
# cudatoolkit                                        632.8MB @  45.7MB/s 13.3s
# tensorflow-hub                                      76.9kB @   5.5kB/s  0.1s
# [+] 13.9s
# Downloading  (5)   51%
# Extracting  (124)  ⣾  python                                              60.1MB @   4.3MB/s  1.1s
# bzip2                                              260.2kB @  18.7kB/s  0.1s
# gmp                                                460.1kB @  33.0kB/s  0.0s
# nspr                                               228.6kB @  16.4kB/s  0.1s
# libblas                                             14.4kB @   1.0kB/s  0.1s
# [+] 14.0s
# Downloading  (5)   51%
# Extracting  (128)  ⣾  pygments                                           860.4kB @  61.4kB/s  0.1s
# openjpeg                                           546.2kB @  38.9kB/s  0.1s
# tornado                                            666.3kB @  47.4kB/s  0.1s
# imageio                                            292.1kB @  20.7kB/s  0.1s
# [+] 14.1s
# Downloading  (5)   51%
# Extracting  (133)  ⣾  pykalman                                           231.6kB @  16.4kB/s  0.1s
# libsodium                                          375.0kB @  26.5kB/s  0.1s
# wheel                                               57.6kB @   4.1kB/s  0.0s
# [+] 14.2s
# Downloading  (5)   52%
# Extracting  (136)  ⣾  pyzmq                                              511.6kB @  36.0kB/s  0.1s
# seaborn                                              6.3kB @ 443.0 B/s  0.1s
# libbrotlidec                                        34.6kB @   2.4kB/s  0.1s
# [+] 14.3s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 14.4s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 14.5s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 14.6s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 14.7s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 14.8s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 14.9s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.0s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.1s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.2s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.3s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.4s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.5s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.6s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.7s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.8s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 15.9s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  [+] 16.0s
# Downloading  (5)   52%
# Extracting  (139)  ⣾  ca-certificates                                    146.5kB @   9.1kB/s  1.8s
# [+] 16.1s
# Downloading  (5)   52%
# Extracting  (140)  ⣾  matplotlib                                           7.2kB @ 447.0 B/s  4.0s
# krb5                                                 1.3MB @  82.3kB/s  1.8s
# libexpat                                            76.8kB @   4.8kB/s  0.0s
# [+] 16.2s
# Downloading  (5)   52%
# Extracting  (142)  ⣾  libpng                                             288.2kB @  17.8kB/s  0.1s
# pywavelets                                           4.6MB @ 283.5kB/s  0.2s
# libstdcxx                                            5.9MB @ 359.3kB/s  0.2s
# [+] 16.3s
# Downloading  (5)   53%
# Extracting  (145)  ⣾  jsmin                                               15.8kB @ 965.0 B/s  0.1s
# libgettextpo-devel                                  37.4kB @   2.3kB/s  0.1s
# [+] 16.4s
# Downloading  (4)   54%
# Extracting  (147)  ⣾  pyparsing                                           90.1kB @   5.5kB/s  0.1s
# [+] 16.5s
# Downloading  (3)   54%
# Extracting  (147)  ⣾  [+] 16.6s
# Downloading  (3)   55%
# Extracting  (146)  ⣾  [+] 16.7s
# Downloading  (3)   55%
# Extracting  (145)  ⣾  scikit-learn                                         8.2MB @ 490.9kB/s  0.6s
# [+] 16.8s
# Downloading  (2)   56%
# Extracting  (146)  ⣾  [+] 16.9s
# Downloading  (2)   56%
# Extracting  (146)  ⣾  [+] 17.0s
# Downloading  (2)   57%
# Extracting  (146)  ⣾  [+] 17.1s
# Downloading  (2)   58%
# Extracting  (146)  ⣾  [+] 17.2s
# Downloading  (2)   58%
# Extracting  (146)  ⣾  [+] 17.3s
# Downloading  (2)   58%
# Extracting  (146)  ⣾  [+] 17.4s
# Downloading  (2)   59%
# Extracting  (146)  ⣾  [+] 17.5s
# Downloading  (2)   59%
# Extracting  (146)  ⣾  [+] 17.6s
# Downloading  (2)   60%
# Extracting  (146)  ⣾  [+] 17.7s
# Downloading  (2)   60%
# Extracting  (146)  ⣾  [+] 17.8s
# Downloading  (2)   61%
# Extracting  (146)  ⣾  [+] 17.9s
# Downloading  (2)   61%
# Extracting  (146)  ⣾  [+] 18.0s
# Downloading  (2)   62%
# Extracting  (146)  ⣾  [+] 18.1s
# Downloading  (2)   62%
# Extracting  (146)  ⣾  [+] 18.2s
# Downloading  (2)   62%
# Extracting  (146)  ⣾  [+] 18.3s
# Downloading  (2)   63%
# Extracting  (146)  ⣾  [+] 18.4s
# Downloading  (2)   63%
# Extracting  (146)  ⣾  [+] 18.5s
# Downloading  (2)   63%
# Extracting  (146)  ⣾  [+] 18.6s
# Downloading  (2)   64%
# Extracting  (146)  ⣾  [+] 18.7s
# Downloading  (2)   64%
# Extracting  (145)  ⣾  [+] 18.8s
# Downloading  (2)   65%
# Extracting  (145)  ⣾  [+] 18.9s
# Downloading  (2)   65%
# Extracting  (144)  ⣾  [+] 19.0s
# Downloading  (2)   65%
# Extracting  (143)  ⣾  [+] 19.1s
# Downloading  (2)   65%
# Extracting  (142)  ⣾  [+] 19.2s
# Downloading  (2)   66%
# Extracting  (142)  ⣾  [+] 19.3s
# Downloading  (2)   66%
# Extracting  (141)  ⣾  [+] 19.4s
# Downloading  (2)   67%
# Extracting  (140)  ⣾  [+] 19.5s
# Downloading  (2)   67%
# Extracting  (140)  ⣾  [+] 19.6s
# Downloading  (2)   67%
# Extracting  (140)  ⣾  [+] 19.7s
# Downloading  (2)   67%
# Extracting  (140)  ⣾  [+] 19.8s
# Downloading  (2)   68%
# Extracting  (140)  ⣾  [+] 19.9s
# Downloading  (2)   68%
# Extracting  (140)  ⣾  [+] 20.0s
# Downloading  (2)   69%
# Extracting  (140)  ⣾  [+] 20.1s
# Downloading  (2)   69%
# Extracting  (140)  ⣾  [+] 20.2s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.3s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.4s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.5s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.6s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.7s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.8s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 20.9s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.0s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.1s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.2s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.3s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.4s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.5s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.6s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.7s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.8s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 21.9s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 22.0s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 22.1s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 22.2s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 22.3s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 22.4s
# Downloading  (2)   70%
# Extracting  (140)  ⣾  [+] 22.5s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 22.6s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 22.7s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 22.8s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 22.9s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.0s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.1s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.2s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.3s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.4s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.5s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.6s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.7s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.8s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 23.9s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 24.0s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 24.1s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 24.2s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 24.3s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 24.4s
# Downloading  (2)   71%
# Extracting  (140)  ⣾  [+] 24.5s
# Downloading  (2)   72%
# Extracting  (140)  ⣾  [+] 24.6s
# Downloading  (2)   72%
# Extracting  (140)  ⣾  [+] 24.7s
# Downloading  (2)   72%
# Extracting  (140)  ⣾  [+] 24.8s
# Downloading  (2)   73%
# Extracting  (140)  ⣾  [+] 24.9s
# Downloading  (2)   73%
# Extracting  (140)  ⣾  [+] 25.0s
# Downloading  (2)   74%
# Extracting  (140)  ⣾  [+] 25.1s
# Downloading  (2)   74%
# Extracting  (140)  ⣾  [+] 25.2s
# Downloading  (2)   75%
# Extracting  (140)  ⣾  [+] 25.3s
# Downloading  (2)   75%
# Extracting  (140)  ⣾  [+] 25.4s
# Downloading  (2)   76%
# Extracting  (140)  ⣾  [+] 25.5s
# Downloading  (2)   77%
# Extracting  (140)  ⣾  [+] 25.6s
# Downloading  (2)   77%
# Extracting  (139)  ⣾  [+] 25.7s
# Downloading  (2)   78%
# Extracting  (139)  ⣾  [+] 25.8s
# Downloading  (2)   78%
# Extracting  (138)  ⣾  [+] 25.9s
# Downloading  (2)   79%
# Extracting  (138)  ⣾  [+] 26.0s
# Downloading  (2)   79%
# Extracting  (137)  ⣾  [+] 26.1s
# Downloading  (2)   80%
# Extracting  (137)  ⣾  [+] 26.2s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.3s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.4s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.5s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.6s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.7s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.8s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 26.9s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 27.0s
# Downloading  (2)   81%
# Extracting  (136)  ⣾  [+] 27.1s
# Downloading  (2)   81%
# Extracting  (135)  ⣾  [+] 27.2s
# Downloading  (2)   81%
# Extracting  (135)  ⣾  [+] 27.3s
# Downloading  (2)   81%
# Extracting  (135)  ⣾  [+] 27.4s
# Downloading  (2)   81%
# Extracting  (135)  ⣾  [+] 27.5s
# Downloading  (2)   81%
# Extracting  (135)  ⣾  [+] 27.6s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 27.7s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 27.8s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 27.9s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.0s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.1s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.2s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.3s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.4s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.5s
# Downloading  (2)   82%
# Extracting  (135)  ⣾  [+] 28.6s
# ...
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:20.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:21.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:22.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:23.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:24.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:25.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:26.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:27.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:28.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:29.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:30.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:31.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:33.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:34.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:35.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:36.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:37.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:38.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:39.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:40.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:41.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:42.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:43.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:44.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:45.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:46.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:47.6s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# \ By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# \ By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA -
#   https://docs.nvidia.com/deeplearning/cudnn/sla/index.html
#
# done
#
# To activate this environment, use
#
#      $ mamba activate sleap_env
#
# To deactivate an active environment, use
#
#      $ mamba deactivate

# %%
# %%bash
#
# # Test if th gpu is available
# source activate sleap_env
# python -c "import sleap; print('SLEAP Version Check:', sleap.__version__)"
# python -c "import tensorflow as tf; print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))"
# Out:
# INFO:matplotlib.font_manager:generated new fontManager
# SLEAP Version Check: 1.3.4
# Num GPUs Available:  1
# 2026-02-19 16:13:34.554973: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:34.686742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:34.689660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# #Running

# %%
# %%bash
# # 1. Load variables
# source /content/sleap_paths.env
# source activate sleap_env
# export MPLBACKEND=Agg
#
# # --- FIX: Clean absolute paths in JSON ---
# python -c "
# import json
# import os
# config_path = os.path.join(os.environ['MODEL_PATH'], 'training_config.json')
# if os.path.exists(config_path):
#     with open(config_path, 'r') as f:
#         config = json.load(f)
#
#     # Remove fixed paths (e.g., H:\...) so SLEAP uses the local .h5 file
#     heads = config.get('model', {}).get('heads', {})
#     for head_name in heads:
#         if isinstance(heads[head_name], dict):
#             for key in list(heads[head_name].keys()):
#                 if 'keras_model_path' in key:
#                     heads[head_name][key] = None
#
#     with open(config_path, 'w') as f:
#         json.dump(config, f, indent=4)
#     print('✅ Model configuration optimized for Colab.')
# "
#
# # 2. Batch Processing
# for video in "$VIDEO_FOLDER"/*.avi; do
#     [ -e "$video" ] || continue
#     filename=$(basename "$video")
#     current_basename="${filename%_crop.avi}"
#
#     echo "------------------------------------------------"
#     echo "PROCESSING: $filename"
#
#     # STEP 1: SLEAP Inference
#     sleap-track "$video" \
#         -m "$MODEL_PATH/training_config.json" \
#         --output "$OUTPUT_FOLDER/${filename}.predictions.slp" \
#         --no-gui
#
#     # STEP 2: Normalization and CSV Generation (Python)
#     export CUR_FILE="$filename"
#     export CUR_BASE="$current_basename"
#
#     python - <<EOF
# import sleap
# import pandas as pd
# import os
# import numpy as np
# from PIL import Image
#
# arenas_path = os.environ.get('ARENAS_FOLDER', '')
# output_path = os.environ.get('OUTPUT_FOLDER', '')
# video_file = os.environ.get('CUR_FILE', '')
# basename = os.environ.get('CUR_BASE', '')
#
# slp_file = os.path.join(output_path, f"{video_file}.predictions.slp")
# csv_output = os.path.join(output_path, f"{basename}_pose.csv")
# png_file = os.path.join(arenas_path, f"{basename}.png")
#
# node_mapping = {'L': 'Left', 'R': 'Right', 'H': 'Head', 'Trx': 'Thorax',
#                 'Abd': 'Abdomen', 'Lw': 'LeftWing', 'Rw': 'RightWing', 'T': 'Top'}
#
# if os.path.exists(slp_file):
#     w, h = 1.0, 1.0
#     if os.path.exists(png_file):
#         with Image.open(png_file) as img:
#             w, h = img.size
#         print(f"-> Arena Resolution: {w}x{h}")
#
#     labels = sleap.load_file(slp_file)
#     data = []
#     for frame in labels:
#         for inst in frame.instances:
#             row = {'FrameIndex': frame.frame_idx}
#             for node in labels.skeleton.nodes:
#                 b_name = node_mapping.get(node.name, node.name)
#                 pt = inst[node.name]
#                 if pt is not None:
#                     row[f'{b_name}.Position.X'] = pt.x / w
#                     row[f'{b_name}.Position.Y'] = pt.y / h
#                     row[f'{b_name}.Confidence'] = pt.score
#                 else:
#                     row[f'{b_name}.Position.X'] = np.nan
#                     row[f'{b_name}.Position.Y'] = np.nan
#                     row[f'{b_name}.Confidence'] = 0.0
#             data.append(row)
#
#     df = pd.DataFrame(data)
#     if not df.empty:
#         df.sort_values('FrameIndex').to_csv(csv_output, index=False, na_rep='NaN')
#         print(f"✅ Success: {basename}_pose.csv generated.")
# EOF
# done
# echo "================================================"
# echo "PROCESS COMPLETE!"
# Out:
# ✅ Configuração do modelo otimizada para o Colab.
# ------------------------------------------------
# A PROCESSAR: MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi
# Started inference at: 2026-02-19 16:13:49.477861
# Args:
# {
# │   'data_path': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi',
# │   'models': ['/content/Sleap_Colab/training_config.json'],
# │   'frames': '',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp',
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'max_instances': None,
# │   'tracking.tracker': None,
# │   'tracking.max_tracking': None,
# │   'tracking.max_tracks': None,
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 14910 MiB of free memory.
# Versions:
# SLEAP: 1.3.4
# TensorFlow: 2.7.0
# Numpy: 1.19.5
# Python: 3.7.12
# OS: Linux-6.6.105+-x86_64-with-debian-bookworm-sid
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 164.7 FPS
# Finished inference at: 2026-02-19 16:17:04.018851
# Total runtime: 194.54101848602295 secs
# Predicted frames: 36600/36600
# Provenance:
# {
# │   'model_paths': ['/content/Sleap_Colab/training_config.json'],
# │   'predictor': 'SingleInstancePredictor',
# │   'sleap_version': '1.3.4',
# │   'platform': 'Linux-6.6.105+-x86_64-with-debian-bookworm-sid',
# │   'command': '/usr/local/envs/sleap_env/bin/sleap-track /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi -m /content/Sleap_Colab/training_config.json --output /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp --no-gui',
# │   'data_path': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi',
# │   'output_path': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp',
# │   'total_elapsed': 194.54101848602295,
# │   'start_timestamp': '2026-02-19 16:13:49.477861',
# │   'finish_timestamp': '2026-02-19 16:17:04.018851'
# }
#
# Saved output: /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp
# -> Resolução da Arena: 652x647
# ✅ Sucesso: MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_pose.csv gerado.
# ================================================
# PROCESSO CONCLUÍDO!
# 2026-02-19 16:13:49.608235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:49.621458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:49.624032: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:49.783061: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-19 16:13:49.783649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:49.786565: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:49.788939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:50.637422: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:50.639584: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:50.641259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-19 16:13:50.642821: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13603 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2026-02-19 16:13:57.041068: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8201
