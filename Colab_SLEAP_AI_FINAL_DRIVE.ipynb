# %% [markdown]
# #SLEAP_AI.ipnyb

# %% [markdown]
# #Description
# ---------
# This notebook runs SLEAP.ai in the colab Virtual Machine.
#
# It uses the power of NVIDIA Tesla T4 GPU to take the best out of SLEAP running it's deep learning neural networks faster.
#
# The system used is condacolab since it helps bypass default python limitations from colab
#
# SLEAP is run inside an environment where it has the necessary drivers.

# %% [markdown]
# Run order
#
# 1.   Choose the Paths.
# 2.   Prepare the environment
# 3.   Run SLEAP
# 4.   Output the predictions

# %% [markdown]
# SLEAP.ai DOI 🔗 https://doi.org/10.1038/s41592-022-01426-1
#
# Moita Lab 🔗 https://moitalab.org/

# %% [markdown]
# #Define Paths

# %%
import os
from ipyfilechooser import FileChooser
from IPython.display import display, clear_output
import ipywidgets as widgets
from google.colab import drive

# Mount Google Drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# --- INTERFACE CONFIGURATION ---

# 1. Selector for the Experience Folder (Root)
chooser_exp = FileChooser('/content/drive/MyDrive/')
chooser_exp.title = '<b>1. Select Experience Folder (Root)</b>'
chooser_exp.show_only_dirs = True

# 2. Selector for the SLEAP Model
chooser_model = FileChooser('/content/drive/MyDrive/')
chooser_model.title = '<b>2. Select SLEAP Model (.json or folder)</b>'

# Confirmation Button
save_button = widgets.Button(
    description='Confirm and Configure Folders',
    button_style='success',
    icon='check',
    layout=widgets.Layout(width='350px')
)

output_log = widgets.Output()

def on_confirm_clicked(b):
    with output_log:
        clear_output()

        exp_root = chooser_exp.selected_path
        model_path = chooser_model.selected

        if not exp_root or not model_path:
            print("❌ Error: Please select both the Experience Folder and the Model!")
            return

        # Moita Lab Hierarchy
        crop_raw = os.path.join(exp_root, "PostProcessing", "CropRaw")
        arenas = os.path.join(exp_root, "PostProcessing", "Arenas")
        pose_folder = os.path.join(exp_root, "PostProcessing", "Pose")

        # Subfolder verification
        if not os.path.exists(crop_raw) or not os.path.exists(arenas):
            print(f"❌ Error: Could not find the required structure in:\n{exp_root}")
            print("Please ensure 'PostProcessing/CropRaw' and 'PostProcessing/Arenas' exist.")
            return

        # Create Pose folder
        if not os.path.exists(pose_folder):
            os.makedirs(pose_folder)
            print(f"✅ Pose folder created: {pose_folder}")
        else:
            print(f"📂 Pose folder already exists.")

        # Save paths for the Bash environment
        with open('/content/sleap_paths.env', 'w') as f:
            f.write(f'export VIDEO_FOLDER="{crop_raw}"\n')
            f.write(f'export ARENAS_FOLDER="{arenas}"\n')
            f.write(f'export OUTPUT_FOLDER="{pose_folder}"\n')
            f.write(f'export MODEL_PATH="{model_path}"\n')

        print("-" * 40)
        print("🚀 PIPELINE SYNCED AND READY!")
        print(f"Experience: {os.path.basename(exp_root)}")
        print(f"Videos in: .../CropRaw")
        print(f"Images in: .../Arenas")
        print("-" * 40)

save_button.on_click(on_confirm_clicked)

display(chooser_exp, chooser_model, save_button, output_log)
# Out:
# Mounted at /content/drive
# FileChooser(path='/content/drive/MyDrive', filename='', title='<b>1. Selecionar Experience Folder (Root)</b>',…
# FileChooser(path='/content/drive/MyDrive', filename='', title='<b>2. Selecionar Modelo SLEAP (.json ou pasta)<…
# Button(button_style='success', description='Confirmar e Configurar Pastas', icon='check', layout=Layout(width=…
# Output()

# %% [markdown]
# #Enviroment preparation

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create a dedicated output folder

# !pip install -q condacolab
import condacolab
condacolab.install() # Runtime will restart
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...

# %%
# !mamba create -y -n sleap_env -c conda-forge -c nvidia -c sleap -c anaconda \
    python=3.7 \
    sleap=1.3.4 \
    tensorflow=2.7.0 \
    cudatoolkit=11.3.1 \
    cudnn=8.2.1.32 \
    pandas=1.3.5 \
    scipy=1.7.3 \
    matplotlib=3.5.3
# Out:
# Looking for: ['python=3.7', 'sleap=1.3.4', 'tensorflow=2.7.0', 'cudatoolkit=11.3.1', 'cudnn=8.2.1.32', 'pandas=1.3.5', 'scipy=1.7.3', 'matplotlib=3.5.3']
#
# [+] 0.0s
# nvidia/linux-64 (check zst)                        Checked  0.1s
# [+] 0.0s
# nvidia/noarch (che..  ⣾  nvidia/noarch (check zst)
# [+] 0.0s
# sleap/linux-64 (ch..  ⣾  [+] 0.1s
# sleap/linux-64 (ch..  ⣾  [+] 0.2s
# sleap/linux-64 (ch..  ⣾  [+] 0.3s
# sleap/linux-64 (ch..  ⣾  sleap/linux-64 (check zst)
# [+] 0.0s
# [+] 0.1s
# sleap/noarch (chec..  ⣾  [+] 0.2s
# sleap/noarch (chec..  ⣾  sleap/noarch (check zst)
# [+] 0.0s
# anaconda/linux-64 ..  ⣾  anaconda/linux-64 (check zst)
# [+] 0.0s
# anaconda/noarch (c..  ⣾  anaconda/noarch (check zst)
# [+] 0.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# nvidia/linux-64       ⣾
# nvidia/noarch         ⣾
# sleap/linux-64        ⣾  [+] 0.1s
# conda-forge/linux-64   1%
# conda-forge/noarch    ⣾
# nvidia/linux-64       ⣾
# nvidia/noarch         ⣾
# sleap/linux-64        ⣾  [+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     1%
# nvidia/linux-64       22%
# nvidia/noarch         ⣾
# sleap/linux-64        ⣾  nvidia/noarch
# [+] 0.3s
# conda-forge/linux-64   3%
# conda-forge/noarch     1%
# nvidia/linux-64       53%
# sleap/linux-64        ⣾
# sleap/noarch          ⣾  nvidia/linux-64
# sleap/linux-64
# [+] 0.4s
# conda-forge/linux-64   4%
# conda-forge/noarch     4%
# sleap/noarch          ⣾
# anaconda/linux-64      1%
# anaconda/noarch        4%anaconda/noarch
# sleap/noarch
# [+] 0.5s
# conda-forge/linux-64   9%
# conda-forge/noarch    10%
# anaconda/linux-64     18%[+] 0.6s
# conda-forge/linux-64  10%
# conda-forge/noarch    12%
# anaconda/linux-64     45%[+] 0.7s
# conda-forge/linux-64  11%
# conda-forge/noarch    14%
# anaconda/linux-64     48%[+] 0.8s
# conda-forge/linux-64  12%
# conda-forge/noarch    15%
# anaconda/linux-64     63%[+] 0.9s
# conda-forge/linux-64  14%
# conda-forge/noarch    19%
# anaconda/linux-64     78%[+] 1.0s
# conda-forge/linux-64  15%
# conda-forge/noarch    21%
# anaconda/linux-64     90%anaconda/linux-64
# [+] 1.1s
# conda-forge/linux-64  17%
# conda-forge/noarch    24%[+] 1.2s
# conda-forge/linux-64  18%
# conda-forge/noarch    29%[+] 1.3s
# conda-forge/linux-64  21%
# conda-forge/noarch    31%[+] 1.4s
# conda-forge/linux-64  23%
# conda-forge/noarch    37%[+] 1.5s
# conda-forge/linux-64  26%
# conda-forge/noarch    44%[+] 1.6s
# conda-forge/linux-64  28%
# conda-forge/noarch    47%[+] 1.7s
# conda-forge/linux-64  31%
# conda-forge/noarch    53%[+] 1.8s
# conda-forge/linux-64  35%
# conda-forge/noarch    63%[+] 1.9s
# conda-forge/linux-64  39%
# conda-forge/noarch    71%[+] 2.0s
# conda-forge/linux-64  46%
# conda-forge/noarch    84%[+] 2.1s
# conda-forge/linux-64  49%
# conda-forge/noarch    88%conda-forge/noarch
# [+] 2.2s
# conda-forge/linux-64  51%[+] 2.3s
# conda-forge/linux-64  59%[+] 2.4s
# conda-forge/linux-64  70%[+] 2.5s
# conda-forge/linux-64  79%[+] 2.6s
# conda-forge/linux-64  89%conda-forge/linux-64
# Transaction
#
#   Prefix: /usr/local/envs/sleap_env
#
#   Updating specs:
#
#    - python=3.7
#    - sleap=1.3.4
#    - tensorflow=2.7.0
#    - cudatoolkit=11.3.1
#    - cudnn=8.2.1.32
#    - pandas=1.3.5
#    - scipy=1.7.3
#    - matplotlib=3.5.3
#
#
#   Package                    Version  Build                   Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────
#
#   + cuda-nvcc                11.3.58  h2467b9f_0              nvidia            57MB
#   + python_abi                   3.7  4_cp37m                 conda-forge        6kB
#   + ld_impl_linux-64          2.45.1  bootstrap_ha15bf96_1    conda-forge      726kB
#   + libgomp                   15.2.0  he0feb66_18             conda-forge      603kB
#   + _openmp_mutex                4.5  20_gnu                  conda-forge       29kB
#   + libgcc                    15.2.0  he0feb66_18             conda-forge        1MB
#   + c-ares                    1.34.6  hb03c661_0              conda-forge      208kB
#   + libbrotlicommon            1.2.0  hb03c661_1              conda-forge       80kB
#   + yaml                       0.2.5  h280c20c_3              conda-forge       85kB
#   + xorg-renderproto          0.11.1  hb9d3cd8_1003           conda-forge       12kB
#   + libexpat                   2.7.4  hecca717_0              conda-forge       77kB
#   + keyutils                   1.6.3  hb9d3cd8_0              conda-forge      134kB
#   + libiconv                    1.18  h3b78370_2              conda-forge      790kB
#   + libuuid                   2.41.3  h5347b49_0              conda-forge       40kB
#   + xorg-xproto               7.0.31  hb9d3cd8_1008           conda-forge       73kB
#   + xorg-kbproto               1.0.7  hb9d3cd8_1003           conda-forge       30kB
#   + xorg-xextproto             7.3.0  hb9d3cd8_1004           conda-forge       31kB
#   + xorg-libice                1.1.2  hb9d3cd8_0              conda-forge       59kB
#   + bzip2                      1.0.8  hda65f42_9              conda-forge      260kB
#   + xorg-libxdmcp              1.1.5  hb03c661_1              conda-forge       21kB
#   + xorg-libxau               1.0.12  hb03c661_1              conda-forge       15kB
#   + pthread-stubs                0.4  hb9d3cd8_1002           conda-forge        8kB
#   + libwebp-base               1.6.0  hd42ef1d_0              conda-forge      429kB
#   + liblzma                    5.8.2  hb03c661_0              conda-forge      113kB
#   + libffi                     3.4.6  h2dba641_1              conda-forge       57kB
#   + libgfortran5              15.2.0  h68bc16d_18             conda-forge        2MB
#   + ncurses                      6.5  h2d0b736_3              conda-forge      892kB
#   + libnsl                     2.0.1  hb9d3cd8_1              conda-forge       34kB
#   + libstdcxx                 15.2.0  h934c35e_18             conda-forge        6MB
#   + libgcc-ng                 15.2.0  h69a702a_18             conda-forge       28kB
#   + libbrotlienc               1.2.0  hb03c661_1              conda-forge      298kB
#   + libbrotlidec               1.2.0  hb03c661_1              conda-forge       35kB
#   + expat                      2.7.4  hecca717_0              conda-forge      145kB
#   + libgettextpo              0.25.1  h3f43e3d_1              conda-forge      188kB
#   + gettext-tools             0.25.1  h3f43e3d_1              conda-forge        4MB
#   + xorg-libsm                 1.2.6  he73a12e_0              conda-forge       28kB
#   + xz-tools                   5.8.2  hb03c661_0              conda-forge       96kB
#   + xz-gpl-tools               5.8.2  ha02ee65_0              conda-forge       34kB
#   + liblzma-devel              5.8.2  hb03c661_0              conda-forge      465kB
#   + libgfortran               15.2.0  h69a702a_18             conda-forge       28kB
#   + libedit             3.1.20250104  pl5321h7949ede_0        conda-forge      135kB
#   + readline                     8.3  h853b02a_0              conda-forge      345kB
#   + libasprintf               0.25.1  h3f43e3d_1              conda-forge       54kB
#   + nspr                        4.38  h29cc59b_0              conda-forge      229kB
#   + lerc                       4.0.0  h0aef613_1              conda-forge      264kB
#   + pixman                    0.46.4  h54a6638_1              conda-forge      451kB
#   + graphite2                 1.3.14  hecca717_2              conda-forge      100kB
#   + libstdcxx-ng              15.2.0  hdf11a46_18             conda-forge       28kB
#   + libev                       4.33  hd590300_2              conda-forge     Cached
#   + alsa-lib                 1.2.3.2  h166bdaf_0              conda-forge      567kB
#   + libsodium                 1.0.18  h36c2ea0_1              conda-forge      375kB
#   + x264                  1!161.3030  h7f98852_1              conda-forge        3MB
#   + lame                       3.100  h166bdaf_1003           conda-forge      508kB
#   + nettle                       3.6  he412f7d_0              conda-forge        7MB
#   + libxcb                      1.13  h7f98852_1004           conda-forge      400kB
#   + libdeflate                  1.14  h166bdaf_0              conda-forge       83kB
#   + jpeg                          9e  h0b41bf4_3              conda-forge      240kB
#   + libzlib                   1.2.13  h4ab18f5_6              conda-forge       62kB
#   + brotli-bin                 1.2.0  hb03c661_1              conda-forge       21kB
#   + libgettextpo-devel        0.25.1  h3f43e3d_1              conda-forge       37kB
#   + xz                         5.8.2  ha02ee65_0              conda-forge       24kB
#   + libgfortran-ng            15.2.0  h69a702a_18             conda-forge       28kB
#   + libasprintf-devel         0.25.1  h3f43e3d_1              conda-forge       35kB
#   + geos                      3.11.0  h27087fc_0              conda-forge        2MB
#   + gmp                        6.3.0  hac33072_2              conda-forge      460kB
#   + icu                         68.2  h9c3ff4c_0              conda-forge       14MB
#   + cudatoolkit               11.3.1  hb98b00a_13             conda-forge      633MB
#   + zeromq                     4.3.5  h59595ed_1              conda-forge      343kB
#   + gnutls                    3.6.13  h85f3911_1              conda-forge        2MB
#   + xorg-libx11                1.8.4  h0b41bf4_0              conda-forge      830kB
#   + jasper                   1.900.1  h07fcdf6_1006           conda-forge      293kB
#   + libllvm11                 11.1.0  he0ac6c6_5              conda-forge       30MB
#   + zstd                       1.5.6  ha6fb4c9_0              conda-forge     Cached
#   + pcre2                      10.43  hcad00b1_0              conda-forge      951kB
#   + libpng                    1.6.43  h2797004_0              conda-forge      288kB
#   + tk                        8.6.13  noxft_h4845f30_101      conda-forge     Cached
#   + libsqlite                 3.46.0  hde9e2c9_0              conda-forge      865kB
#   + zlib                      1.2.13  h4ab18f5_6              conda-forge       93kB
#   + brotli                     1.2.0  hed03a55_1              conda-forge       20kB
#   + libopenblas               0.3.25  pthreads_h413a1c8_0     conda-forge        6MB
#   + gettext                   0.25.1  h3f43e3d_1              conda-forge      541kB
#   + cudnn                   8.2.1.32  h86fa8c9_0              conda-forge      707MB
#   + xorg-libxext               1.3.4  h0b41bf4_2              conda-forge       50kB
#   + xorg-libxrender           0.9.10  h7f98852_1003           conda-forge       33kB
#   + libclang                  11.1.0  default_ha53f305_1      conda-forge       20MB
#   + libtiff                    4.4.0  h82bc61c_5              conda-forge      485kB
#   + libglib                   2.80.2  hf974151_0              conda-forge        4MB
#   + freetype                  2.12.1  h267a509_2              conda-forge      635kB
#   + nss                        3.100  hca3bf56_0              conda-forge        2MB
#   + sqlite                    3.46.0  h6d4b2fc_0              conda-forge      860kB
#   + libxml2                   2.9.12  h72842e0_0              conda-forge      791kB
#   + openh264                   2.1.1  h780b84a_0              conda-forge        2MB
#   + libprotobuf               3.16.0  h780b84a_0              conda-forge        3MB
#   + libblas                    3.9.0  20_linux64_openblas     conda-forge       14kB
#   + openjpeg                   2.5.0  h7d73246_1              conda-forge      546kB
#   + lcms2                       2.14  h6ed2654_0              conda-forge      262kB
#   + gstreamer                 1.18.5  h9f60fe5_3              conda-forge        2MB
#   + glib-tools                2.80.2  hb6ce0ca_0              conda-forge      114kB
#   + dbus                      1.13.6  h5008d03_3              conda-forge      619kB
#   + fontconfig                2.14.2  h14ed4e7_0              conda-forge      272kB
#   + libxslt                   1.1.33  h15afd5d_2              conda-forge      535kB
#   + libxkbcommon               1.0.3  he3ba5ed_0              conda-forge      595kB
#   + ffmpeg                     4.3.2  h37c90e5_3              conda-forge       10MB
#   + libcblas                   3.9.0  20_linux64_openblas     conda-forge       14kB
#   + liblapack                  3.9.0  20_linux64_openblas     conda-forge       14kB
#   + cairo                     1.16.0  h6cf1ce9_1008           conda-forge        2MB
#   + liblapacke                 3.9.0  20_linux64_openblas     conda-forge       14kB
#   + harfbuzz                   2.9.1  h83ec7ef_1              conda-forge        2MB
#   + ca-certificates         2026.1.4  hbd8a1cb_0              conda-forge      147kB
#   + openssl                   1.1.1w  hd590300_0              conda-forge        2MB
#   + mysql-common              8.0.32  h14678bc_0              conda-forge      803kB
#   + libevent                  2.1.10  h9b69904_4              conda-forge        1MB
#   + krb5                      1.20.1  hf9c8cef_0              conda-forge        1MB
#   + libssh2                   1.10.0  haa6b8db_3              conda-forge      239kB
#   + libnghttp2                1.51.0  hdcd2b5c_0              conda-forge      623kB
#   + python                    3.7.12  hb7a2778_100_cpython    conda-forge       60MB
#   + mysql-libs                8.0.32  h54cf53e_0              conda-forge        2MB
#   + libcurl                   7.87.0  h6312ad2_0              conda-forge      347kB
#   + setuptools                59.8.0  py37h89c1867_1          conda-forge        1MB
#   + hdf5                      1.10.6  nompi_h6a2412b_1114     conda-forge        3MB
#   + libpq                      12.15  h37d81fd_1              anaconda           3MB
#   + wheel                     0.42.0  pyhd8ed1ab_0            conda-forge       58kB
#   + pip                         24.0  pyhd8ed1ab_0            conda-forge        1MB
#   + locket                     1.0.0  pyhd8ed1ab_0            conda-forge        8kB
#   + fsspec                  2023.1.0  pyhd8ed1ab_0            conda-forge      109kB
#   + munkres                    1.1.4  pyh9f0ad1d_0            conda-forge       12kB
#   + pyparsing                  3.1.4  pyhd8ed1ab_0            conda-forge       90kB
#   + cycler                    0.11.0  pyhd8ed1ab_0            conda-forge       10kB
#   + certifi                2024.8.30  pyhd8ed1ab_0            conda-forge      164kB
#   + toolz                     0.12.1  pyhd8ed1ab_0            conda-forge       52kB
#   + cloudpickle                2.2.1  pyhd8ed1ab_0            conda-forge       28kB
#   + threadpoolctl              3.1.0  pyh8a188c0_0            conda-forge       18kB
#   + joblib                     1.3.2  pyhd8ed1ab_0            conda-forge      221kB
#   + cached_property            1.5.2  pyha770c72_1            conda-forge       11kB
#   + mdurl                      0.1.2  pyhd8ed1ab_0            conda-forge       15kB
#   + six                       1.16.0  pyh6c4a22f_0            conda-forge       14kB
#   + packaging                   23.2  pyhd8ed1ab_0            conda-forge       49kB
#   + pygments                  2.17.2  pyhd8ed1ab_0            conda-forge      860kB
#   + typing_extensions          4.7.1  pyha770c72_0            conda-forge       36kB
#   + jsonpickle                   1.2  py_0                    conda-forge       28kB
#   + attrs                     21.4.0  pyhd8ed1ab_0            conda-forge       50kB
#   + pytz                      2024.2  pyhd8ed1ab_0            conda-forge      187kB
#   + jsmin                      3.0.1  pyhd8ed1ab_0            conda-forge       16kB
#   + partd                      1.4.1  pyhd8ed1ab_0            conda-forge       21kB
#   + cached-property            1.5.2  hd8ed1ab_1              conda-forge        4kB
#   + python-dateutil            2.9.0  pyhd8ed1ab_0            conda-forge      223kB
#   + qtpy                       2.4.2  pyhdecd6ff_0            conda-forge       62kB
#   + typing-extensions          4.7.1  hd8ed1ab_0              conda-forge       10kB
#   + markdown-it-py             2.2.0  pyhd8ed1ab_0            conda-forge       62kB
#   + cattrs                     1.1.1  pyhd8ed1ab_0            conda-forge       18kB
#   + rich                      13.8.1  pyhd8ed1ab_0            conda-forge      185kB
#   + unicodedata2              14.0.0  py37h540881e_1          conda-forge      508kB
#   + glib                      2.80.2  hf974151_0              conda-forge      600kB
#   + pyzmq                     24.0.1  py37h0c0c2a8_0          conda-forge      512kB
#   + pyyaml                       6.0  py37h540881e_4          conda-forge      182kB
#   + python-rapidjson             1.9  py37hd23a5d3_0          conda-forge      248kB
#   + psutil                     5.9.3  py37h540881e_0          conda-forge      357kB
#   + tornado                      6.2  py37h540881e_0          conda-forge      666kB
#   + pyqt5-sip                4.19.18  py37hcd2ae1e_8          conda-forge      317kB
#   + pillow                     9.2.0  py37h850a105_2          conda-forge       47MB
#   + numpy                     1.21.6  py37h976b520_0          conda-forge        6MB
#   + cytoolz                   0.12.0  py37h540881e_0          conda-forge      389kB
#   + protobuf                  3.16.0  py37hcd2ae1e_0          conda-forge      350kB
#   + kiwisolver                 1.4.4  py37h7cecad7_0          conda-forge       75kB
#   + fonttools                 4.38.0  py37h540881e_0          conda-forge        2MB
#   + gst-plugins-base          1.14.5  h0935bb2_2              conda-forge        7MB
#   + imagecodecs-lite       2019.12.3  py37hc105733_5          conda-forge      181kB
#   + pywavelets                 1.3.0  py37hda87dfa_1          conda-forge        5MB
#   + shapely                    1.8.5  py37ha4e3bd1_0          conda-forge      362kB
#   + h5py                       3.1.0  nompi_py37h1e651dc_100  conda-forge        1MB
#   + scipy                      1.7.3  py37hf2a6cf1_0          conda-forge       23MB
#   + pandas                     1.3.5  py37he8f5f7f_0          conda-forge       13MB
#   + matplotlib-base            3.5.3  py37hf395dca_2          conda-forge        8MB
#   + qt                        5.12.9  h9d6b050_2              conda-forge      104MB
#   + scikit-learn                 1.0  py37hf0f1638_1          conda-forge        8MB
#   + pyside2                   5.13.2  py37hfa98aef_7          conda-forge       14MB
#   + pyqt-impl                 5.12.3  py37hac37412_8          conda-forge        6MB
#   + libopencv                  4.5.3  py37h25009ff_1          conda-forge       36MB
#   + pyqtwebengine             5.12.1  py37he336c9b_8          conda-forge      179kB
#   + pyqtchart                   5.12  py37he336c9b_8          conda-forge      263kB
#   + py-opencv                  4.5.3  py37h6531663_1          conda-forge        1MB
#   + pyqt                      5.12.3  py37h89c1867_8          conda-forge       22kB
#   + opencv                     4.5.3  py37h89c1867_1          conda-forge       21kB
#   + matplotlib                 3.5.3  py37h89c1867_2          conda-forge        7kB
#   + tensorflow                 2.7.0  py37hb93dfd8_3          sleap            515MB
#   + dask-core               2022.2.0  pyhd8ed1ab_0            conda-forge      822kB
#   + patsy                      0.5.6  pyhd8ed1ab_0            conda-forge      187kB
#   + imageio                   2.36.0  pyh12aca89_1            conda-forge      292kB
#   + tifffile                2020.6.3  py_0                    conda-forge      111kB
#   + pykalman                   0.9.7  pyhd8ed1ab_0            conda-forge      232kB
#   + scikit-video              1.1.11  pyh24bf2e0_0            conda-forge        2MB
#   + seaborn-base              0.12.2  pyhd8ed1ab_0            conda-forge      232kB
#   + networkx                     2.7  pyhd8ed1ab_0            conda-forge        2MB
#   + tensorflow-hub            0.13.0  pyh56297ac_0            conda-forge       77kB
#   + statsmodels               0.13.2  py37hda87dfa_0          conda-forge       12MB
#   + scikit-image              0.19.2  py37he8f5f7f_0          conda-forge       13MB
#   + seaborn                   0.12.2  hd8ed1ab_0              conda-forge        6kB
#   + imgaug                     0.4.0  pyhd8ed1ab_1            conda-forge      853kB
#   + sleap                      1.3.4  py37_2                  sleap              5MB
#
#   Summary:
#
#   Install: 199 packages
#
#   Total download: 2GB
#
# ──────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%python_abi                                           6.4kB @  73.8kB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (1)  ⣾  _openmp_mutex                                       28.9kB @ 249.2kB/s  0.1s
# ld_impl_linux-64                                   725.8kB @   5.1MB/s  0.1s
# libgomp                                            603.3kB @   3.8MB/s  0.2s
# yaml                                                85.2kB @ 520.5kB/s  0.0s
# libgcc                                               1.0MB @   5.9MB/s  0.1s
# keyutils                                           134.1kB @ 741.6kB/s  0.0s
# xorg-xproto                                         73.3kB @ 365.1kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   1%
# Extracting   (8)  ⣾  xorg-libxau                                         15.3kB @  61.0kB/s  0.1s
# liblzma                                            113.2kB @ 449.8kB/s  0.1s
# xorg-libice                                         58.6kB @ 231.2kB/s  0.1s
# ncurses                                            891.6kB @   3.5MB/s  0.1s
# libgcc-ng                                           27.5kB @  93.8kB/s  0.0s
# libbrotlienc                                       298.4kB @   1.0MB/s  0.0s
# [+] 0.3s
# Downloading  (5)   1%
# Extracting  (12)  ⣾  libgettextpo                                       188.3kB @ 620.1kB/s  0.1s
# liblzma-devel                                      465.1kB @   1.5MB/s  0.0s
# libasprintf                                         53.6kB @ 164.0kB/s  0.0s
# libstdcxx-ng                                        27.6kB @  72.6kB/s  0.1s
# readline                                           345.1kB @ 896.9kB/s  0.1s
# libxcb                                             399.9kB @   1.0MB/s  0.1s
# alsa-lib                                           567.0kB @   1.5MB/s  0.1s
# [+] 0.4s
# Downloading  (5)   2%
# Extracting  (17)  ⣾  libzlib                                             61.6kB @ 145.4kB/s  0.0s
# xz                                                  24.1kB @  53.8kB/s  0.1s
# libgfortran-ng                                      27.5kB @  61.4kB/s  0.1s
# gmp                                                460.1kB @   1.0MB/s  0.1s
# [+] 0.5s
# Downloading  (5)   2%
# Extracting  (19)  ⣾  jasper                                             292.7kB @ 577.4kB/s  0.1s
# xorg-libx11                                        829.9kB @   1.6MB/s  0.1s
# pcre2                                              950.8kB @   1.8MB/s  0.1s
# xorg-libxrender                                     32.9kB @  59.2kB/s  0.0s
# [+] 0.6s
# Downloading  (5)   3%
# Extracting  (22)  ⣾  sqlite                                             860.4kB @   1.4MB/s  0.1s
# libprotobuf                                          2.6MB @   4.0MB/s  0.1s
# libglib                                              3.9MB @   6.1MB/s  0.1s
# lcms2                                              262.1kB @ 390.4kB/s  0.1s
# [+] 0.7s
# Downloading  (5)   4%
# Extracting  (25)  ⣾  liblapack                                           14.3kB @  19.9kB/s  0.0s
# dbus                                               618.6kB @ 854.5kB/s  0.1s
# libxkbcommon                                       594.8kB @ 804.6kB/s  0.1s
# harfbuzz                                             2.1MB @   2.7MB/s  0.1s
# [+] 0.8s
# Downloading  (5)   4%
# Extracting  (29)  ⣾  mysql-common                                       803.0kB @ 994.4kB/s  0.1s
# libevent                                             1.2MB @   1.3MB/s  0.1s
# mysql-libs                                           1.5MB @   1.8MB/s  0.1s
# [+] 0.9s
# Downloading  (5)   5%
# Extracting  (30)  ⣾  cuda-nvcc                                           56.8MB @  62.1MB/s  0.9s
# munkres                                             12.5kB @  13.5kB/s  0.1s
# libllvm11                                           30.2MB @  32.4MB/s  0.5s
# pip                                                  1.4MB @   1.5MB/s  0.1s
# threadpoolctl                                       18.3kB @  19.0kB/s  0.0s
# mdurl                                               14.7kB @  15.2kB/s  0.0s
# certifi                                            163.8kB @ 166.4kB/s  0.1s
# hdf5                                                 3.2MB @   3.2MB/s  0.2s
# pygments                                           860.4kB @ 868.3kB/s  0.1s
# [+] 1.0s
# Downloading  (5)   5%
# Extracting  (39)  ⣾  partd                                               20.7kB @  20.7kB/s  0.0s
# cattrs                                              18.3kB @  17.6kB/s  0.1s
# attrs                                               50.0kB @  46.5kB/s  0.1s
# pyqt5-sip                                          317.4kB @ 292.2kB/s  0.0s
# python-rapidjson                                   247.8kB @ 228.1kB/s  0.1s
# rich                                               185.4kB @ 169.1kB/s  0.1s
# [+] 1.1s
# Downloading  (5)   5%
# Extracting  (42)  ⣾  [+] 1.2s
# Downloading  (6)   5%
# Extracting  (42)  ⣾  qtpy                                                62.4kB @  53.2kB/s  0.2s
# fonttools                                            2.0MB @   1.6MB/s  0.2s
# [+] 1.3s
# Downloading  (5)   6%
# Extracting  (43)  ⣾  gst-plugins-base                                     7.1MB @   5.2MB/s  0.3s
# [+] 1.4s
# Downloading  (5)   6%
# Extracting  (43)  ⣾  pyqtchart                                          263.3kB @ 185.0kB/s  0.1s
# [+] 1.5s
# Downloading  (5)   7%
# Extracting  (43)  ⣾  opencv                                              21.4kB @  13.7kB/s  0.1s
# [+] 1.6s
# Downloading  (5)   7%
# Extracting  (43)  ⣾  pyqt-impl                                            6.2MB @   3.7MB/s  0.4s
# [+] 1.7s
# Downloading  (5)   8%
# Extracting  (43)  ⣾  tifffile                                           111.2kB @  63.7kB/s  0.1s
# dask-core                                          822.4kB @ 466.5kB/s  0.2s
# [+] 1.8s
# Downloading  (5)   8%
# Extracting  (45)  ⣾  seaborn-base                                       231.9kB @ 127.9kB/s  0.1s
# scipy                                               22.8MB @  12.6MB/s  0.7s
# [+] 1.9s
# Downloading  (5)   9%
# Extracting  (46)  ⣾  imgaug                                             853.1kB @ 446.6kB/s  0.1s
# libiconv                                           790.2kB @ 400.3kB/s  0.1s
# statsmodels                                         11.7MB @   5.9MB/s  0.2s
# [+] 2.0s
# Downloading  (5)   9%
# Extracting  (49)  ⣾  xorg-xextproto                                      30.5kB @  15.2kB/s  0.0s
# pthread-stubs                                        8.3kB @   4.1kB/s  0.0s
# libbrotlidec                                        34.6kB @  16.7kB/s  0.0s
# pillow                                              47.2MB @  22.8MB/s  1.0s
# libgfortran5                                         2.5MB @   1.2MB/s  0.1s
# [+] 2.1s
# Downloading  (5)  10%
# Extracting  (54)  ⣾  libgfortran                                         27.5kB @  13.0kB/s  0.0s
# xorg-libsm                                          27.6kB @  13.0kB/s  0.0s
# lerc                                               264.2kB @ 123.4kB/s  0.1s
# libsodium                                          375.0kB @ 172.2kB/s  0.1s
# [+] 2.2s
# Downloading  (5)  10%
# Extracting  (57)  ⣾  brotli-bin                                          21.0kB @   9.5kB/s  0.0s
# nettle                                               6.8MB @   3.1MB/s  0.1s
# libsqlite                                          865.3kB @ 383.3kB/s  0.0s
# zeromq                                             343.4kB @ 151.8kB/s  0.1s
# [+] 2.3s
# Downloading  (5)  11%
# Extracting  (61)  ⣾  geos                                                 1.7MB @ 729.8kB/s  0.1s
# xorg-libxext                                        50.1kB @  21.6kB/s  0.1s
# freetype                                           635.0kB @ 267.6kB/s  0.1s
# libopenblas                                          5.5MB @   2.3MB/s  0.1s
# [+] 2.4s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  nss                                                  2.0MB @ 852.4kB/s  0.1s
# [+] 2.5s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 2.6s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 2.7s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 2.8s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 2.9s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 3.0s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 3.1s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.2s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.3s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.4s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.5s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.6s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.7s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.8s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 3.9s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.0s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.1s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.2s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  libxslt                                            534.6kB @ 128.0kB/s  1.9s
# [+] 4.3s
# Downloading  (5)  11%
# Extracting  (65)  ⣾  [+] 4.4s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.5s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.6s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.7s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.8s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 4.9s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 5.0s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 5.1s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 5.2s
# Downloading  (5)  11%
# Extracting  (64)  ⣾  [+] 5.3s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 5.4s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 5.5s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 5.6s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 5.7s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 5.8s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 5.9s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.0s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.1s
# Downloading  (5)  11%
# Extracting  (62)  ⣾  [+] 6.2s
# Downloading  (5)  11%
# Extracting  (62)  ⣾  gstreamer                                            2.1MB @ 350.8kB/s  3.8s
# [+] 6.3s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.4s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.5s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.6s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.7s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.8s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 6.9s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 7.0s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  [+] 7.1s
# Downloading  (5)  11%
# Extracting  (63)  ⣾  cairo                                                1.6MB @ 220.8kB/s  4.8s
# libnghttp2                                         622.7kB @  86.8kB/s  1.0s
# openssl                                              2.0MB @ 272.2kB/s  2.9s
# sleap                                                4.5MB @ 630.4kB/s  5.4s
# [+] 7.2s
# Downloading  (5)  12%
# Extracting  (67)  ⣾  locket                                               8.2kB @   1.1kB/s  0.0s
# cycler                                              10.3kB @   1.4kB/s  0.0s
# packaging                                           49.5kB @   6.8kB/s  0.0s
# joblib                                             221.2kB @  30.5kB/s  0.1s
# pytz                                               187.0kB @  25.7kB/s  0.1s
# [+] 7.3s
# Downloading  (5)  12%
# Extracting  (72)  ⣾  python-dateutil                                    222.7kB @  30.5kB/s  0.0s
# pyyaml                                             182.0kB @  24.8kB/s  0.1s
# unicodedata2                                       508.2kB @  69.2kB/s  0.1s
# setuptools                                           1.1MB @ 145.8kB/s  0.2s
# kiwisolver                                          74.5kB @  10.1kB/s  0.0s
# [+] 7.4s
# Downloading  (5)  12%
# Extracting  (77)  ⣾  numpy                                                6.4MB @ 864.8kB/s  0.1s
# shapely                                            361.5kB @  48.3kB/s  0.1s
# [+] 7.5s
# Downloading  (5)  13%
# Extracting  (79)  ⣾  patsy                                              187.2kB @  24.9kB/s  0.0s
# pyqt                                                22.5kB @   3.0kB/s  0.1s
# h5py                                                 1.3MB @ 165.5kB/s  0.2s
# [+] 7.6s
# Downloading  (5)  14%
# Extracting  (82)  ⣾  libbrotlicommon                                     80.0kB @  10.5kB/s  0.0s
# scikit-video                                         2.3MB @ 294.7kB/s  0.1s
# libuuid                                             40.3kB @   5.3kB/s  0.1s
# [+] 7.7s
# Downloading  (5)  15%
# Extracting  (85)  ⣾  xorg-libxdmcp                                       20.6kB @   2.7kB/s  0.0s
# libwebp-base                                       429.0kB @  55.4kB/s  0.1s
# [+] 7.8s
# Downloading  (5)  16%
# Extracting  (87)  ⣾  libedit                                            134.7kB @  17.3kB/s  0.1s
# gettext-tools                                        3.6MB @ 464.7kB/s  0.1s
# graphite2                                           99.6kB @  12.7kB/s  0.1s
# qt                                                 104.3MB @  13.3MB/s  6.7s
# libdeflate                                          82.7kB @  10.5kB/s  0.0s
# [+] 7.9s
# Downloading  (5)  17%
# Extracting  (92)  ⣾  scikit-image                                        12.6MB @   1.6MB/s  0.4s
# libasprintf-devel                                   34.7kB @   4.4kB/s  0.0s
# libpng                                             288.2kB @  36.3kB/s  0.1s
# gnutls                                               2.1MB @ 264.0kB/s  0.1s
# glib-tools                                         114.4kB @  14.4kB/s  0.0s
# libtiff                                            484.8kB @  60.8kB/s  0.1s
# [+] 8.0s
# Downloading  (5)  18%
# Extracting  (98)  ⣾  libopencv                                           36.2MB @   4.5MB/s  0.6s
# libcblas                                            14.4kB @   1.8kB/s  0.1s
# libcurl                                            347.4kB @  43.3kB/s  0.1s
# krb5                                                 1.3MB @ 165.0kB/s  0.1s
# fsspec                                             108.9kB @  13.5kB/s  0.0s
# cached_property                                     11.1kB @   1.4kB/s  0.0s
# cloudpickle                                         27.9kB @   3.5kB/s  0.1s
# cached-property                                      4.1kB @ 511.0 B/s  0.0s
# glib                                               600.4kB @  74.2kB/s  0.1s
# [+] 8.1s
# Downloading  (5)   18%
# Extracting  (107)  ⣾  pyqtwebengine                                      178.7kB @  22.0kB/s  0.0s
# tornado                                            666.3kB @  81.9kB/s  0.1s
# libclang                                            20.2MB @   2.5MB/s  0.2s
# imagecodecs-lite                                   181.3kB @  22.2kB/s  0.1s
# c-ares                                             207.9kB @  25.4kB/s  0.0s
# [+] 8.2s
# Downloading  (5)   19%
# Extracting  (112)  ⣾  xorg-kbproto                                        30.2kB @   3.7kB/s  0.0s
# bzip2                                              260.2kB @  31.6kB/s  0.0s
# pywavelets                                           4.6MB @ 558.6kB/s  0.2s
# pixman                                             451.0kB @  54.5kB/s  0.0s
# networkx                                             1.6MB @ 194.4kB/s  0.1s
# xz-tools                                            96.1kB @  11.6kB/s  0.1s
# [+] 8.3s
# Downloading  (5)   19%
# Extracting  (118)  ⣾  jpeg                                               240.4kB @  28.9kB/s  0.0s
# zlib                                                92.9kB @  11.2kB/s  0.0s
# brotli                                              20.1kB @   2.4kB/s  0.1s
# fontconfig                                         272.0kB @  32.5kB/s  0.1s
# ca-certificates                                    146.5kB @  17.5kB/s  0.0s
# [+] 8.4s
# Downloading  (5)   19%
# Extracting  (123)  ⣾  six                                                 14.3kB @   1.7kB/s  0.0s
# toolz                                               52.4kB @   6.2kB/s  0.0s
# libpq                                                3.0MB @ 352.9kB/s  0.1s
# markdown-it-py                                      62.4kB @   7.4kB/s  0.1s
# [+] 8.5s
# Downloading  (5)   20%
# Extracting  (127)  ⣾  cytoolz                                            388.6kB @  45.5kB/s  0.1s
# [+] 8.6s
# Downloading  (5)   20%
# Extracting  (128)  ⣾  pykalman                                           231.6kB @  26.8kB/s  0.1s
# xorg-renderproto                                    11.9kB @   1.4kB/s  0.0s
# matplotlib-base                                      7.7MB @ 885.1kB/s  0.2s
# [+] 8.7s
# Downloading  (5)   21%
# Extracting  (131)  ⣾  libnsl                                              33.7kB @   3.9kB/s  0.0s
# xz-gpl-tools                                        33.8kB @   3.9kB/s  0.1s
# lame                                               508.3kB @  58.0kB/s  0.1s
# scikit-learn                                         8.2MB @ 939.7kB/s  0.3s
# [+] 8.8s
# Downloading  (5)   21%
# Extracting  (135)  ⣾  libblas                                             14.4kB @   1.6kB/s  0.0s
# gettext                                            541.4kB @  61.4kB/s  0.1s
# openh264                                             1.6MB @ 179.5kB/s  0.1s
# typing_extensions                                   36.3kB @   4.1kB/s  0.1s
# typing-extensions                                   10.1kB @   1.1kB/s  0.1s
# [+] 8.9s
# Downloading  (5)   22%
# Extracting  (140)  ⣾  [+] 9.0s
# Downloading  (5)   22%
# Extracting  (140)  ⣾  protobuf                                           349.9kB @  38.9kB/s  0.1s
# tensorflow-hub                                      76.9kB @   8.5kB/s  0.1s
# [+] 9.1s
# Downloading  (5)   23%
# Extracting  (142)  ⣾  pandas                                              13.3MB @   1.5MB/s  0.3s
# libffi                                              57.4kB @   6.3kB/s  0.1s
# nspr                                               228.6kB @  24.9kB/s  0.0s
# [+] 9.2s
# Downloading  (5)   24%
# Extracting  (145)  ⣾  openjpeg                                           546.2kB @  58.9kB/s  0.1s
# [+] 9.3s
# Downloading  (5)   24%
# Extracting  (146)  ⣾  libssh2                                            239.5kB @  25.7kB/s  0.0s
# [+] 9.4s
# Downloading  (5)   25%
# Extracting  (147)  ⣾  [+] 9.5s
# Downloading  (5)   25%
# Extracting  (147)  ⣾  [+] 9.6s
# Downloading  (5)   25%
# Extracting  (147)  ⣾  [+] 9.7s
# Downloading  (5)   25%
# Extracting  (147)  ⣾  [+] 9.8s
# Downloading  (5)   25%
# Extracting  (147)  ⣾  jsonpickle                                          28.3kB @   2.9kB/s  0.5s
# [+] 9.9s
# Downloading  (4)   25%
# Extracting  (148)  ⣾  [+] 10.0s
# Downloading  (4)   25%
# Extracting  (148)  ⣾  [+] 10.1s
# Downloading  (4)   25%
# Extracting  (148)  ⣾  psutil                                             356.8kB @  35.0kB/s  0.1s
# [+] 10.2s
# Downloading  (4)   25%
# Extracting  (149)  ⣾  icu                                                 13.8MB @   1.3MB/s  1.1s
# libexpat                                            76.8kB @   7.5kB/s  0.1s
# [+] 10.3s
# Downloading  (4)   26%
# Extracting  (151)  ⣾  matplotlib                                           7.2kB @ 699.0 B/s  0.1s
# libgettextpo-devel                                  37.4kB @   3.6kB/s  0.1s
# [+] 10.4s
# Downloading  (5)   27%
# Extracting  (153)  ⣾  x264                                                 2.6MB @ 247.0kB/s  0.1s
# wheel                                               57.6kB @   5.5kB/s  0.1s
# [+] 10.5s
# Downloading  (5)   27%
# Extracting  (155)  ⣾  pyzmq                                              511.6kB @  48.4kB/s  0.1s
# [+] 10.6s
# Downloading  (5)   28%
# Extracting  (156)  ⣾  expat                                              145.3kB @  13.7kB/s  0.0s
# [+] 10.7s
# Downloading  (5)   28%
# Extracting  (157)  ⣾  [+] 10.8s
# Downloading  (5)   29%
# Extracting  (157)  ⣾  python                                              60.1MB @   5.5MB/s  2.1s
# [+] 10.9s
# Downloading  (5)   29%
# Extracting  (158)  ⣾  ffmpeg                                              10.3MB @ 943.0kB/s  0.3s
# [+] 11.0s
# Downloading  (5)   30%
# Extracting  (159)  ⣾  pyside2                                             14.2MB @   1.3MB/s  0.6s
# seaborn                                              6.3kB @ 575.0 B/s  0.0s
# jsmin                                               15.8kB @   1.4kB/s  0.2s
# liblapacke                                          14.4kB @   1.3kB/s  0.1s
# libxml2                                            790.7kB @  71.3kB/s  0.1s
# [+] 11.1s
# Downloading  (5)   31%
# Extracting  (164)  ⣾  imageio                                            292.1kB @  26.3kB/s  0.1s
# [+] 11.2s
# Downloading  (5)   31%
# Extracting  (165)  ⣾  py-opencv                                            1.2MB @ 102.4kB/s  0.2s
# [+] 11.3s
# Downloading  (5)   31%
# Extracting  (166)  ⣾  pyparsing                                           90.1kB @   8.0kB/s  0.1s
# [+] 11.4s
# Downloading  (4)   32%
# Extracting  (167)  ⣾  libstdcxx                                            5.9MB @ 511.8kB/s  0.3s
# [+] 11.5s
# Downloading  (3)   32%
# Extracting  (168)  ⣾  [+] 11.6s
# Downloading  (3)   33%
# Extracting  (168)  ⣾  [+] 11.7s
# Downloading  (3)   33%
# Extracting  (168)  ⣾  [+] 11.8s
# Downloading  (3)   34%
# Extracting  (168)  ⣾  [+] 11.9s
# Downloading  (3)   35%
# Extracting  (168)  ⣾  [+] 12.0s
# Downloading  (3)   35%
# Extracting  (168)  ⣾  [+] 12.1s
# Downloading  (3)   35%
# Extracting  (168)  ⣾  [+] 12.2s
# Downloading  (3)   36%
# Extracting  (168)  ⣾  [+] 12.3s
# Downloading  (3)   36%
# Extracting  (167)  ⣾  [+] 12.4s
# Downloading  (3)   36%
# Extracting  (167)  ⣾  [+] 12.5s
# Downloading  (3)   37%
# Extracting  (167)  ⣾  [+] 12.6s
# Downloading  (3)   38%
# Extracting  (166)  ⣾  [+] 12.7s
# Downloading  (3)   38%
# Extracting  (166)  ⣾  [+] 12.8s
# Downloading  (3)   39%
# Extracting  (166)  ⣾  [+] 12.9s
# Downloading  (3)   39%
# Extracting  (166)  ⣾  [+] 13.0s
# Downloading  (3)   40%
# Extracting  (166)  ⣾  [+] 13.1s
# Downloading  (3)   41%
# Extracting  (166)  ⣾  [+] 13.2s
# Downloading  (3)   42%
# Extracting  (166)  ⣾  [+] 13.3s
# Downloading  (3)   42%
# Extracting  (166)  ⣾  [+] 13.4s
# Downloading  (3)   43%
# Extracting  (166)  ⣾  [+] 13.5s
# Downloading  (3)   43%
# Extracting  (166)  ⣾  [+] 13.6s
# Downloading  (3)   44%
# Extracting  (166)  ⣾  [+] 13.7s
# Downloading  (3)   45%
# Extracting  (166)  ⣾  [+] 13.8s
# Downloading  (3)   45%
# Extracting  (166)  ⣾  [+] 13.9s
# Downloading  (3)   46%
# Extracting  (166)  ⣾  [+] 14.0s
# Downloading  (3)   46%
# Extracting  (165)  ⣾  [+] 14.1s
# Downloading  (3)   46%
# Extracting  (165)  ⣾  [+] 14.2s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.3s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.4s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.5s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.6s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.7s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.8s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 14.9s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 15.0s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 15.1s
# Downloading  (3)   46%
# Extracting  (164)  ⣾  [+] 15.2s
# Downloading  (3)   46%
# Extracting  (163)  ⣾  [+] 15.3s
# Downloading  (3)   47%
# Extracting  (163)  ⣾  [+] 15.4s
# Downloading  (3)   48%
# Extracting  (163)  ⣾  [+] 15.5s
# Downloading  (3)   48%
# Extracting  (162)  ⣾  [+] 15.6s
# Downloading  (3)   49%
# Extracting  (162)  ⣾  [+] 15.7s
# Downloading  (3)   50%
# Extracting  (161)  ⣾  [+] 15.8s
# Downloading  (3)   51%
# Extracting  (161)  ⣾  [+] 15.9s
# Downloading  (3)   52%
# Extracting  (161)  ⣾  [+] 16.0s
# Downloading  (3)   53%
# Extracting  (161)  ⣾  [+] 16.1s
# Downloading  (3)   54%
# Extracting  (161)  ⣾  [+] 16.2s
# Downloading  (3)   55%
# Extracting  (161)  ⣾  [+] 16.3s
# Downloading  (3)   55%
# Extracting  (161)  ⣾  [+] 16.4s
# Downloading  (3)   56%
# Extracting  (161)  ⣾  [+] 16.5s
# Downloading  (3)   56%
# Extracting  (160)  ⣾  [+] 16.6s
# Downloading  (3)   57%
# Extracting  (160)  ⣾  [+] 16.7s
# Downloading  (3)   58%
# Extracting  (160)  ⣾  [+] 16.8s
# Downloading  (3)   59%
# Extracting  (160)  ⣾  [+] 16.9s
# Downloading  (3)   60%
# Extracting  (159)  ⣾  [+] 17.0s
# Downloading  (3)   60%
# Extracting  (159)  ⣾  [+] 17.1s
# Downloading  (3)   61%
# Extracting  (159)  ⣾  [+] 17.2s
# Downloading  (3)   62%
# Extracting  (158)  ⣾  [+] 17.3s
# Downloading  (3)   63%
# Extracting  (158)  ⣾  [+] 17.4s
# Downloading  (3)   64%
# Extracting  (157)  ⣾  [+] 17.5s
# Downloading  (3)   64%
# Extracting  (156)  ⣾  [+] 17.6s
# Downloading  (3)   65%
# Extracting  (156)  ⣾  [+] 17.7s
# Downloading  (3)   65%
# Extracting  (155)  ⣾  [+] 17.8s
# Downloading  (3)   66%
# Extracting  (154)  ⣾  [+] 17.9s
# Downloading  (3)   67%
# Extracting  (154)  ⣾  [+] 18.0s
# Downloading  (3)   68%
# Extracting  (154)  ⣾  [+] 18.1s
# Downloading  (3)   68%
# Extracting  (153)  ⣾  [+] 18.2s
# Downloading  (3)   69%
# Extracting  (152)  ⣾  [+] 18.3s
# Downloading  (3)   70%
# Extracting  (152)  ⣾  [+] 18.4s
# Downloading  (3)   70%
# Extracting  (151)  ⣾  [+] 18.5s
# Downloading  (3)   71%
# Extracting  (151)  ⣾  [+] 18.6s
# Downloading  (3)   71%
# Extracting  (149)  ⣾  [+] 18.7s
# Downloading  (3)   72%
# Extracting  (147)  ⣾  [+] 18.8s
# Downloading  (3)   72%
# Extracting  (147)  ⣾  [+] 18.9s
# Downloading  (3)   74%
# Extracting  (145)  ⣾  [+] 19.0s
# Downloading  (3)   75%
# Extracting  (145)  ⣾  [+] 19.1s
# Downloading  (3)   75%
# Extracting  (145)  ⣾  [+] 19.2s
# Downloading  (3)   76%
# Extracting  (145)  ⣾  [+] 19.3s
# Downloading  (3)   77%
# Extracting  (145)  ⣾  [+] 19.4s
# Downloading  (3)   77%
# Extracting  (145)  ⣾  [+] 19.5s
# Downloading  (3)   78%
# Extracting  (145)  ⣾  [+] 19.6s
# Downloading  (3)   79%
# Extracting  (145)  ⣾  [+] 19.7s
# Downloading  (3)   79%
# Extracting  (145)  ⣾  [+] 19.8s
# Downloading  (3)   79%
# Extracting  (145)  ⣾  [+] 19.9s
# Downloading  (3)   80%
# Extracting  (145)  ⣾  [+] 20.0s
# Downloading  (3)   80%
# Extracting  (145)  ⣾  [+] 20.1s
# Downloading  (3)   80%
# Extracting  (145)  ⣾  [+] 20.2s
# Downloading  (3)   80%
# Extracting  (145)  ⣾  [+] 20.3s
# Downloading  (3)   81%
# Extracting  (145)  ⣾  [+] 20.4s
# Downloading  (3)   82%
# Extracting  (144)  ⣾  [+] 20.5s
# Downloading  (3)   83%
# Extracting  (144)  ⣾  [+] 20.6s
# Downloading  (3)   84%
# Extracting  (144)  ⣾  [+] 20.7s
# Downloading  (3)   85%
# Extracting  (144)  ⣾  [+] 20.8s
# Downloading  (3)   85%
# Extracting  (144)  ⣾  [+] 20.9s
# Downloading  (3)   86%
# Extracting  (144)  ⣾  cudatoolkit                                        632.8MB @  30.2MB/s 12.7s
# [+] 21.0s
# Downloading  (2)   86%
# Extracting  (145)  ⣾  [+] 21.1s
# Downloading  (2)   86%
# Extracting  (145)  ⣾  [+] 21.2s
# Downloading  (2)   87%
# Extracting  (144)  ⣾  [+] 21.3s
# Downloading  (2)   88%
# Extracting  (144)  ⣾  [+] 21.4s
# Downloading  (2)   88%
# Extracting  (142)  ⣾  [+] 21.5s
# Downloading  (2)   88%
# Extracting  (142)  ⣾  [+] 21.6s
# Downloading  (2)   89%
# Extracting  (142)  ⣾  [+] 21.7s
# Downloading  (2)   90%
# Extracting  (141)  ⣾  [+] 21.8s
# Downloading  (2)   91%
# Extracting  (140)  ⣾  [+] 21.9s
# Downloading  (2)   91%
# Extracting  (140)  ⣾  [+] 22.0s
# Downloading  (2)   92%
# Extracting  (139)  ⣾  [+] 22.1s
# Downloading  (2)   92%
# Extracting  (139)  ⣾  [+] 22.2s
# Downloading  (2)   93%
# Extracting  (139)  ⣾  [+] 22.3s
# Downloading  (2)   94%
# Extracting  (139)  ⣾  [+] 22.4s
# Downloading  (2)   94%
# Extracting  (138)  ⣾  [+] 22.5s
# Downloading  (2)   95%
# Extracting  (138)  ⣾  tensorflow                                         515.0MB @  22.8MB/s 14.4s
# [+] 22.6s
# ...
# Extracting  (51)  ⣾  [+] 3m:5.0s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 3m:5.1s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 3m:5.2s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 3m:5.3s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 3m:5.4s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 3m:5.5s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 3m:5.6s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 3m:5.7s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 3m:5.8s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 3m:5.9s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 3m:6.0s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 3m:6.1s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 3m:6.2s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.3s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.4s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.5s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.6s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.7s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.8s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:6.9s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:7.0s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 3m:7.1s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 3m:7.2s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 3m:7.3s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 3m:7.4s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 3m:7.5s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 3m:7.6s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 3m:7.7s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 3m:7.8s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 3m:7.9s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 3m:8.0s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 3m:8.1s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 3m:8.2s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 3m:8.3s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 3m:8.4s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 3m:8.5s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 3m:8.6s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 3m:8.7s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 3m:8.8s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 3m:8.9s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.0s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.1s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.2s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.3s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.4s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.5s
# Downloading      100%
# Extracting  (36)  ⣾  [+] 3m:9.6s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3m:9.7s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3m:9.8s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3m:9.9s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3m:10.0s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 3m:10.1s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 3m:10.2s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 3m:10.3s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 3m:10.4s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 3m:10.5s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 3m:10.6s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 3m:10.7s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 3m:10.8s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 3m:10.9s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.0s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.1s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.2s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.3s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.4s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.5s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.6s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.7s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.8s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:11.9s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.0s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.1s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.2s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.3s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.4s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.5s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.6s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.7s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.8s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:12.9s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.0s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.1s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.2s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.3s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.4s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.5s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.6s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.7s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 3m:13.8s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 3m:13.9s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 3m:14.0s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 3m:14.1s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 3m:14.2s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 3m:14.3s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 3m:14.4s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 3m:14.5s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 3m:14.6s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 3m:14.7s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 3m:14.8s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 3m:14.9s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 3m:15.0s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 3m:15.1s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 3m:15.2s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 3m:15.3s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 3m:15.4s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 3m:15.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:15.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:15.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:15.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:15.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.6s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:16.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.3s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.4s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.5s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 3m:17.6s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 3m:17.7s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 3m:17.8s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 3m:17.9s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 3m:18.0s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.1s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.2s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.3s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.4s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.5s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.6s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.7s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:18.9s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.0s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.1s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.2s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.3s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.4s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.5s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.6s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.7s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:19.9s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.0s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.1s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.2s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.3s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.4s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.5s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.6s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.7s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:20.9s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 3m:21.0s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 3m:21.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:21.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:22.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:23.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:24.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:25.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:26.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:27.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.8s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:28.9s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.0s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.1s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.2s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 3m:29.6s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 3m:29.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 3m:29.8s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 3m:29.9s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 3m:30.0s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 3m:30.1s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 3m:30.2s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 3m:30.3s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 3m:30.4s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:30.5s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:30.6s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:30.7s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:30.8s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:30.9s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:31.0s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:31.1s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 3m:31.2s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 3m:31.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 3m:31.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 3m:31.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 3m:31.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 3m:31.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 3m:31.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 3m:31.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 3m:32.0s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 3m:32.1s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 3m:32.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 3m:32.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 3m:32.5s
# Downloading      100%
# Extracting       100%
# Downloading and Extracting Packages:
#
# done
# done
# | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# / By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA -
#   https://docs.nvidia.com/deeplearning/cudnn/sla/index.html
#
# done
#
# To activate this environment, use
#
#      $ mamba activate sleap_env
#
# To deactivate an active environment, use
#
#      $ mamba deactivate

# %%
# %%bash
#
# # Test if th gpu is available
# source activate sleap_env
# python -c "import sleap; print('SLEAP Version Check:', sleap.__version__)"
# python -c "import tensorflow as tf; print('Num GPUs Available: ', len(tf.config.list_physical_devices('GPU')))"
# Out:
# INFO:matplotlib.font_manager:generated new fontManager
# SLEAP Version Check: 1.3.4
# Num GPUs Available:  1
# 2026-02-18 22:50:18.939164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:19.075354: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:19.078029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %% [markdown]
# #Running

# %%
# %%bash
# source activate sleap_env
# export MPLBACKEND=Agg
# source /content/sleap_paths.env
#
# # Start processing
# for video in "$VIDEO_FOLDER"/*.avi; do
#     [ -e "$video" ] || continue
#     filename=$(basename "$video")
#
#     # Logic: remove '_crop.avi' to find the corresponding arena .png name
#     # We use a clear bash variable to pass to the python environment
#     current_basename="${filename%_crop.avi}"
#
#     echo "------------------------------------------------"
#     echo "PROCESSING: $filename"
#     echo "BASE NAME: $current_basename"
#
#     # 1. Run SLEAP (Inference)
#     sleap-track "$video" \
#         -m "$MODEL_PATH" \
#         -o "$OUTPUT_FOLDER/${filename}.predictions.slp" \
#         --no-gui
#
#     # 2. Python Script for Post-Processing and Normalization
#     # We pass variables via environment arguments to avoid NameErrors
#     export CUR_FILE="$filename"
#     export CUR_BASE="$current_basename"
#
#     python - <<EOF
# import sleap
# import pandas as pd
# import os
# import numpy as np
# from PIL import Image
#
# # Retrieve paths from environment
# arenas_path = os.environ['ARENAS_FOLDER']
# output_path = os.environ['OUTPUT_FOLDER']
# video_filename = os.environ['CUR_FILE']
# basename = os.environ['CUR_BASE']
#
# slp_file = os.path.join(output_path, f"{video_filename}.predictions.slp")
# csv_output = os.path.join(output_path, f"{basename}_pose.csv")
# png_file = os.path.join(arenas_path, f"{basename}.png")
#
# # Node name mapping for Moita Lab / Bonsai standard
# node_mapping = {
#     'L': 'Left', 'R': 'Right', 'H': 'Head', 'Trx': 'Thorax',
#     'Abd': 'Abdomen', 'Lw': 'LeftWing', 'Rw': 'RightWing', 'T': 'Top'
# }
#
# if os.path.exists(slp_file):
#     # Attempt to get real resolution from the arena image
#     if os.path.exists(png_file):
#         with Image.open(png_file) as img:
#             w, h = img.size
#         print(f"-> Arena resolution detected: {w}x{h}")
#     else:
#         print(f"-> WARNING: {png_file} not found. Using 1.0 scale (pixels).")
#         w, h = 1.0, 1.0
#
#     labels = sleap.load_file(slp_file)
#     data = []
#
#     for frame in labels:
#         for inst in frame.instances:
#             row = {'FrameIndex': frame.frame_idx}
#             for node in labels.skeleton.nodes:
#                 b_name = node_mapping.get(node.name, node.name)
#                 pt = inst[node.name]
#
#                 if pt is not None:
#                     row[f'{b_name}.Position.X'] = pt.x / w
#                     row[f'{b_name}.Position.Y'] = pt.y / h
#                     row[f'{b_name}.Confidence'] = pt.score
#                 else:
#                     row[f'{b_name}.Position.X'] = np.nan
#                     row[f'{b_name}.Position.Y'] = np.nan
#                     row[f'{b_name}.Confidence'] = 0.0
#             data.append(row)
#
#     df = pd.DataFrame(data)
#     if not df.empty:
#         parts = ['Left', 'Right', 'Top', 'Head', 'Thorax', 'Abdomen', 'LeftWing', 'RightWing']
#         cols_order = ['FrameIndex']
#         for p in parts:
#             cols_order.extend([f'{p}.Position.X', f'{p}.Position.Y', f'{p}.Confidence'])
#
#         df = df.reindex(columns=[c for c in cols_order if c in df.columns])
#         df = df.sort_values('FrameIndex')
#
#         # Save CSV with explicit "NaN" string
#         df.to_csv(csv_output, index=False, na_rep="NaN")
#         print(f"-> Success: {os.path.basename(csv_output)} generated.")
#     else:
#         print("-> Warning: No instances detected.")
# else:
#     print(f"-> Error: File {slp_file} not found.")
# EOF
#
# done
# echo "================================================"
# echo "PIPELINE COMPLETE!"
# Out:
# ------------------------------------------------
# A PROCESSAR: MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi
# BASE NAME: MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0
# Started inference at: 2026-02-18 22:50:36.077821
# Args:
# {
# │   'data_path': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi',
# │   'models': [
# │   │   '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/SLEAP/NewDataBase/model/251125_130445.single_instance.n=3283/'
# │   ],
# │   'frames': '',
# │   'only_labeled_frames': False,
# │   'only_suggested_frames': False,
# │   'output': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp',
# │   'no_empty_frames': False,
# │   'verbosity': 'rich',
# │   'video.dataset': None,
# │   'video.input_format': 'channels_last',
# │   'video.index': '',
# │   'cpu': False,
# │   'first_gpu': False,
# │   'last_gpu': False,
# │   'gpu': 'auto',
# │   'max_edge_length_ratio': 0.25,
# │   'dist_penalty_weight': 1.0,
# │   'batch_size': 4,
# │   'open_in_gui': False,
# │   'peak_threshold': 0.2,
# │   'max_instances': None,
# │   'tracking.tracker': None,
# │   'tracking.max_tracking': None,
# │   'tracking.max_tracks': None,
# │   'tracking.target_instance_count': None,
# │   'tracking.pre_cull_to_target': None,
# │   'tracking.pre_cull_iou_threshold': None,
# │   'tracking.post_connect_single_breaks': None,
# │   'tracking.clean_instance_count': None,
# │   'tracking.clean_iou_threshold': None,
# │   'tracking.similarity': None,
# │   'tracking.match': None,
# │   'tracking.robust': None,
# │   'tracking.track_window': None,
# │   'tracking.min_new_track_points': None,
# │   'tracking.min_match_points': None,
# │   'tracking.img_scale': None,
# │   'tracking.of_window_size': None,
# │   'tracking.of_max_levels': None,
# │   'tracking.save_shifted_instances': None,
# │   'tracking.kf_node_indices': None,
# │   'tracking.kf_init_frame_count': None
# }
#
# INFO:sleap.nn.inference:Auto-selected GPU 0 with 14910 MiB of free memory.
# Versions:
# SLEAP: 1.3.4
# TensorFlow: 2.7.0
# Numpy: 1.19.5
# Python: 3.7.12
# OS: Linux-6.6.105+-x86_64-with-debian-bookworm-sid
#
# System:
# GPUs: 1/1 available
#   Device: /physical_device:GPU:0
#          Available: True
#         Initalized: False
#      Memory growth: True
#
# Video: /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi
# Predicting... ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% ETA: 0:00:00 229.3 FPS
# Finished inference at: 2026-02-18 22:53:41.050113
# Total runtime: 184.9723162651062 secs
# Predicted frames: 36600/36600
# Provenance:
# {
# │   'model_paths': [
# │   │   '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/SLEAP/NewDataBase/model/251125_130445.single_instance.n=3283/training_config.json'
# │   ],
# │   'predictor': 'SingleInstancePredictor',
# │   'sleap_version': '1.3.4',
# │   'platform': 'Linux-6.6.105+-x86_64-with-debian-bookworm-sid',
# │   'command': '/usr/local/envs/sleap_env/bin/sleap-track /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi -m /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/SLEAP/NewDataBase/model/251125_130445.single_instance.n=3283/ -o /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp --no-gui',
# │   'data_path': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/CropRaw/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi',
# │   'output_path': '/content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp',
# │   'total_elapsed': 184.9723162651062,
# │   'start_timestamp': '2026-02-18 22:50:36.077821',
# │   'finish_timestamp': '2026-02-18 22:53:41.050113'
# }
#
# Saved output: /content/drive/.shortcut-targets-by-id/1EvQfnCVnY3B5N4bSdunnJEZzZHMVxaoS/Matheus_e_Rodrigo/colab_bonsai/PostProcessing/Pose/MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_crop.avi.predictions.slp
# -> Resolução Arenas detectada: 652x647
# -> Sucesso: MF-LC6_X_CS_ChS(Retinal)-1Loom_19Opto(15mWcm2)-Female-4days-FH2-CamA-2025-08-15T14_30_05_fly0_pose.csv gerado.
# ================================================
# PIPELINE CONCLUÍDA!
# 2026-02-18 22:50:36.183816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:36.194634: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:36.197109: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:37.385346: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-18 22:50:37.385964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:37.388830: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:37.391082: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:39.268781: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:39.270768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:39.272380: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2026-02-18 22:50:39.273969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13603 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2026-02-18 22:50:48.112300: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8201
